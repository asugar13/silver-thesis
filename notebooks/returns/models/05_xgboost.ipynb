# %% [markdown]
# # 05 — XGBoost
# Walk-forward XGBoost on weekly silver log-returns with lagged features.
# Same train/val/test split and evaluation metrics as the ARIMA and LSTM notebooks.
#
# ### Roadmap
#
# | § | Step | What happens |
# |---|---|---|
# | 1 | Load features | Read the shared weekly W-FRI frame (`features_weekly.csv`) + `feature_groups.json`; pull the silver target and `split`. |
# | 2 | Build feature groups | Build the EXOG base (silver lags + 6 cross-asset returns) and every ablation group up front, incl. the `EXOG+ALL` kitchen sink. |
# | 3 | Tuning + walk-forward helpers | `tune()` grid-searches per variant via `TimeSeriesSplit(5)` on train+val; `walk_forward()` retrains every 4 weeks (expanding + rolling-100w). |
# | 4 | Variant ladder | The single ladder — EXOG is rung 0, then GS / NonLin / Tech / Macro / FRED / COT / Sentiment groups + `EXOG+ALL`; each run in both windows. |
# | 5 | Evaluate | One table — RMSE / MAE / OOS R² / DA / WDA for Naive, Drift, every variant. Save `metrics_xgboost.csv`. |
# | 6 | Sub-period robustness | Pick the best variant by RMSE (primary) and WDA (secondary); break down by `PERIODS`; save period + preds CSVs. |
# | 7 | Predicted vs actual | Full window, two panels (WDA-best, RMSE-best), drift overlaid. |
# | 8 | Significance tests | Load-bearing DM vs-Drift floor (OOS R² + DM, squared & absolute error). 8b: Pesaran–Timmermann directional lens. 8c: ex-2025 robustness. |
# | 9 | 2026 zoom | WDA-best and RMSE-best vs the drift floor on the 2026 YTD slice. |
# | 10 | Feature importance | Permutation importance (OOS test window) from a single XGBoost fit on the `EXOG+ALL` model — descriptive, not a load-bearing test. |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.dpi'] = 120

# %% [markdown]
# ## 1. Load features

# %%
# Weekly feature frame (built once by 02_features.ipynb §8 — single source of truth).
weekly = pd.read_csv('../../../data/processed/features_weekly.csv', index_col=0, parse_dates=True)

TARGET       = 'silver_return'
EXOG_RETURNS = ['gold_return', 'usd_return', 'copper_return', 'sp500_return',
                'vix_return', 'oil_return']
EXOG_LEVELS  = ['gs_ratio_z']   # level feature — separate group for ablation (see §8)
EXOG         = EXOG_RETURNS + EXOG_LEVELS

# Base weekly matrix: target + cross-asset returns + gs_ratio_z. The frame is un-lagged
# (build_features applies the 1-week lag); the W-FRI aggregation lives in 02_features.
base_cols = [TARGET] + EXOG_RETURNS + EXOG_LEVELS
all_w   = weekly[base_cols].dropna().copy()
n_train = int((weekly.loc[all_w.index, 'split'] != 'test').sum())

print(f'Weekly obs — train+val: {n_train}, test: {len(all_w) - n_train}')
print(f'Features available: {[c for c in EXOG if c in all_w.columns]}')
# Out:
# Weekly obs — train+val: 417, test: 174
# Features available: ['gold_return', 'usd_return', 'copper_return', 'sp500_return', 'vix_return', 'oil_return', 'gs_ratio_z']

# %% [markdown]
# ## 2. Build all feature groups
#
# Build every feature set up front — the EXOG base (silver AR lags + 6 cross-asset return lags) and
# all ablation groups (GS / NonLin / Tech / Macro / FRED_daily / COT / sentiment / BestLag) — so the
# variant ladder (§4) is the *only* place models are fit. Base groups get the 1-week lag here; TECH /
# MACRO are already lagged in the frame; BestLag columns are pre-lagged (used as-is). A missing column
# errors loudly (the frame always carries every group).

# %%
import json
GROUPS = json.load(open('../../../data/processed/feature_groups.json'))

def build_features(df):
    '''EXOG base: 6 lagged cross-asset returns + silver AR lags 1-3 (gs_ratio_z is its own +GS rung).'''
    X = pd.DataFrame(index=df.index)
    for col in [c for c in EXOG_RETURNS if c in df.columns]:
        X[f'{col}_lag1'] = df[col].shift(1)
    for lag in [1, 2, 3]:
        X[f'silver_lag{lag}'] = df[TARGET].shift(lag)
    return X

features_all = build_features(all_w)

# Test target / index (used by the ladder + everything downstream).
y_test     = all_w[TARGET].iloc[n_train:].values
test_index = all_w.index[n_train:]

# -- Ablation groups, each as {feature_name: weekly_series} -----------------------
def lag1(cols):
    return {f'{c}_lag1': weekly[c].shift(1) for c in cols}

GS_COLS       = lag1(GROUPS['GS'])
FRED_COLS     = lag1(GROUPS['FRED_DAILY'])
COT_COLS      = lag1(GROUPS['COT'])
SENT_COLS     = lag1(GROUPS['SENT'])
REDDIT_COLS   = {'reddit_sentiment_lag1': SENT_COLS['reddit_sentiment_lag1']}
NEWS_COLS     = {'news_sentiment_lag1':   SENT_COLS['news_sentiment_lag1']}
NEWSPAID_COLS = {'news_paid_sentiment_title_lag1': weekly['news_paid_sentiment_title'].shift(1)}  # paid-news, title only
SENTPAID_COLS = {**REDDIT_COLS, **NEWSPAID_COLS}         # reddit + paid-news title (paid twin of SENT_COLS)
PMI_COLS      = lag1(GROUPS['PMI'])                      # china_pmi_proxy -- point-in-time level, lagged 1w
MACRO_COLS    = {c: weekly[c] for c in GROUPS['MACRO']}   # leak-corrected, already lagged
MACROCOT_COLS = {**FRED_COLS, **COT_COLS}
tech_dict     = lag1(GROUPS['TECH'])                      # directional -- lagged 1w here, like GS/FRED/COT
BESTLAG_ALL_COLS   = {c: weekly[c] for c in GROUPS['BESTLAG_ALL']}    # pre-lagged (used as-is)
BESTLAG_SIG90_COLS = {c: weekly[c] for c in GROUPS['BESTLAG_SIG90']}
BESTLAG_SIG_COLS   = {c: weekly[c] for c in GROUPS['BESTLAG_SIG']}

SILVER_LAGS = [c for c in features_all.columns if c.startswith('silver_lag')]
ALL_BASE    = list(features_all.columns)                  # silver lags + cross-asset return lags
NONLIN_COLS = {f'{c}_sq': features_all[c] ** 2 for c in features_all.columns}   # squared lags
# Kitchen-sink extras (the EXOG+ALL rung + the feature-importance model).
ALL_EXTRA   = {**GS_COLS, **NONLIN_COLS, **tech_dict, **MACROCOT_COLS, **SENT_COLS}
ALL_EXTRA_PAID = {**GS_COLS, **NONLIN_COLS, **tech_dict, **MACROCOT_COLS, **SENTPAID_COLS}   # EXOG+ALL, paid-news title in the sentiment slot

print(f'EXOG base ({len(ALL_BASE)}):', ALL_BASE)
print(f'EXOG+ALL feature count: {len(ALL_BASE) + len(ALL_EXTRA)}')
# Out:
# EXOG base (9): ['gold_return_lag1', 'usd_return_lag1', 'copper_return_lag1', 'sp500_return_lag1', 'vix_return_lag1', 'oil_return_lag1', 'silver_lag1', 'silver_lag2', 'silver_lag3']
# EXOG+ALL feature count: 36

# %% [markdown]
# ## 3. Tuning + walk-forward helpers
#
# `tune()` grid-searches the XGBoost hyperparameters via `TimeSeriesSplit(5)` CV on **train+val** (no
# test peek). `walk_forward()` does 1-step-ahead forecasting, refitting every 4 weeks, expanding
# (default) or rolling-100w. Each variant is tuned on its **own** feature set in the ladder (§4) — so a
# difference between rungs is the features given each its best hyperparameters, not a shared HP handicap.

# %%
from itertools import product
param_grid = {
    'n_estimators':     [100, 200],
    'max_depth':        [2, 3, 4],
    'learning_rate':    [0.01, 0.05, 0.1],
    'subsample':        [0.7, 0.9],
    'colsample_bytree': [0.7, 0.9],
}
tscv   = TimeSeriesSplit(n_splits=5)
keys   = list(param_grid.keys())
combos = list(product(*param_grid.values()))
print(f'Grid: {len(combos)} combinations per variant')

def tune(X_tr_s, y_tr_s):
    '''Grid-search XGB hyperparameters by TimeSeriesSplit CV-RMSE on train+val.'''
    mask_s = ~np.isnan(X_tr_s).any(axis=1)
    X_tr_s, y_tr_s = X_tr_s[mask_s], y_tr_s[mask_s]
    best_rmse_s, best_params_s = np.inf, {}
    for combo in combos:
        params = dict(zip(keys, combo))
        fold_rmses = []
        for fold_tr, fold_val in tscv.split(X_tr_s):
            m = XGBRegressor(random_state=42, verbosity=0, **params)
            m.fit(X_tr_s[fold_tr], y_tr_s[fold_tr])
            fold_rmses.append(np.sqrt(mean_squared_error(y_tr_s[fold_val], m.predict(X_tr_s[fold_val]))))
        rmse = np.mean(fold_rmses)
        if rmse < best_rmse_s:
            best_rmse_s, best_params_s = rmse, params
    return best_params_s

def walk_forward(all_w, features_all, n_train, feature_cols,
                 retrain_every=4, window=None, **xgb_kwargs):
    '''window=None -> expanding; window=N -> rolling (last N weeks). Refit every retrain_every.'''
    y_all = all_w[TARGET].values
    X_all = features_all[feature_cols].values
    preds = np.full(len(all_w) - n_train, np.nan)
    model = None
    for i, t in enumerate(range(n_train, len(all_w))):
        start = max(0, t - window) if window else 0
        X_tr, y_tr = X_all[start:t], y_all[start:t]
        X_te = X_all[t:t+1]
        mask = ~np.isnan(X_tr).any(axis=1)
        if mask.sum() < 10 or np.isnan(X_te).any():
            continue
        if model is None or i % retrain_every == 0:
            model = XGBRegressor(random_state=42, verbosity=0, **xgb_kwargs)
            model.fit(X_tr[mask], y_tr[mask])
        preds[i] = model.predict(X_te)[0]
    return preds
# Out:
# Grid: 72 combinations per variant

# %% [markdown]
# ## 4. Variant ladder
#
# Every variant — **EXOG is just rung 0** — is tuned on its own feature set and walk-forwarded in both
# windows (expanding + rolling-100w), mirroring the `01_arima` ladder. `Tech` and the BestLag rungs use
# the silver AR base only (no cross-assets); everything else builds on EXOG. Each variant's tuned params
# are stashed in `variant_params` (the `EXOG+ALL` set feeds the feature-importance plot in §10).

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../../src'))
from eval_utils import evaluate, period_metrics, diebold_mariano, PERIODS

all_candidates = {}
variant_params = {}

def run_variant(label, base_cols, extra_cols=None):
    '''Tune on this variant own features, then walk-forward both windows.'''
    print(f"--- {label} ---", flush=True)
    feats = features_all[list(base_cols)].copy()
    for col_name, series in (extra_cols or {}).items():
        feats[col_name] = series.reindex(feats.index).ffill()
    fcols = feats.columns.tolist()
    params = tune(feats.iloc[:n_train][fcols].values, all_w[TARGET].iloc[:n_train].values)
    variant_params[label] = params
    p_exp = walk_forward(all_w, feats, n_train, fcols,             **params)
    p_rol = walk_forward(all_w, feats, n_train, fcols, window=100, **params)
    evaluate(f"{label} expanding",      y_test, p_exp)
    evaluate(f"{label} rolling (100w)", y_test, p_rol)
    all_candidates[f"{label} expanding"]      = p_exp
    all_candidates[f"{label} rolling (100w)"] = p_rol

run_variant("EXOG",                  ALL_BASE)                 # rung 0 -- baseline
run_variant("Tech",                  SILVER_LAGS, tech_dict)
run_variant("EXOG+GS",               ALL_BASE, GS_COLS)
run_variant("EXOG+NonLin",           ALL_BASE, NONLIN_COLS)
run_variant("EXOG+Tech",             ALL_BASE, tech_dict)
run_variant("EXOG+Macro",            ALL_BASE, MACRO_COLS)
run_variant("EXOG+FRED_daily",       ALL_BASE, FRED_COLS)
run_variant("EXOG+COT",              ALL_BASE, COT_COLS)
run_variant("EXOG+FRED_daily+COT",   ALL_BASE, MACROCOT_COLS)
run_variant("EXOG+Reddit+News",      ALL_BASE, SENT_COLS)
run_variant("EXOG+Reddit",           ALL_BASE, REDDIT_COLS)
run_variant("EXOG+News",             ALL_BASE, NEWS_COLS)
run_variant("EXOG+GS+Sentiment",     ALL_BASE, {**GS_COLS, **SENT_COLS})
run_variant("EXOG+NonLin+Sentiment", ALL_BASE, {**NONLIN_COLS, **SENT_COLS})
run_variant("EXOG+Tech+Sentiment",   ALL_BASE, {**tech_dict, **SENT_COLS})
run_variant("EXOG+ALL",              ALL_BASE, ALL_EXTRA)
# Paid-news (title-only) twins -- mirror every GDELT-news rung, news -> news_paid_sentiment_title
run_variant("EXOG+NewsPaid",             ALL_BASE, NEWSPAID_COLS)
run_variant("EXOG+Reddit+NewsPaid",      ALL_BASE, SENTPAID_COLS)
run_variant("EXOG+GS+SentimentPaid",     ALL_BASE, {**GS_COLS, **SENTPAID_COLS})
run_variant("EXOG+NonLin+SentimentPaid", ALL_BASE, {**NONLIN_COLS, **SENTPAID_COLS})
run_variant("EXOG+Tech+SentimentPaid",   ALL_BASE, {**tech_dict, **SENTPAID_COLS})
run_variant("EXOG+ALLPaid",              ALL_BASE, ALL_EXTRA_PAID)
# PMI on the FRED 'Macro' rungs (china_pmi_proxy point-in-time level; not the monthly MACRO rung)
run_variant("EXOG+FRED_daily+PMI",       ALL_BASE, {**FRED_COLS, **PMI_COLS})
run_variant("EXOG+FRED_daily+COT+PMI",   ALL_BASE, {**MACROCOT_COLS, **PMI_COLS})
run_variant("EXOG+ALL+PMI",              ALL_BASE, {**ALL_EXTRA, **PMI_COLS})
run_variant("BestLag-All",   SILVER_LAGS, BESTLAG_ALL_COLS)
run_variant("BestLag-Sig90", SILVER_LAGS, BESTLAG_SIG90_COLS)
run_variant("BestLag-Sig",   SILVER_LAGS, BESTLAG_SIG_COLS)
# Out:
# --- EXOG ---
# EXOG expanding                                 RMSE=0.05194  MAE=0.03739  DA=0.529  WDA=0.580
# EXOG rolling (100w)                            RMSE=0.05319  MAE=0.03804  DA=0.506  WDA=0.524
# --- Tech ---
# Tech expanding                                 RMSE=0.05202  MAE=0.03727  DA=0.529  WDA=0.542
# Tech rolling (100w)                            RMSE=0.05282  MAE=0.03739  DA=0.540  WDA=0.524
# --- EXOG+GS ---
# EXOG+GS expanding                              RMSE=0.05187  MAE=0.03691  DA=0.540  WDA=0.557
# EXOG+GS rolling (100w)                         RMSE=0.05288  MAE=0.03716  DA=0.546  WDA=0.550
# --- EXOG+NonLin ---
# EXOG+NonLin expanding                          RMSE=0.05160  MAE=0.03734  DA=0.546  WDA=0.601
# EXOG+NonLin rolling (100w)                     RMSE=0.05351  MAE=0.03828  DA=0.489  WDA=0.530
# --- EXOG+Tech ---
# EXOG+Tech expanding                            RMSE=0.05236  MAE=0.03741  DA=0.546  WDA=0.560
# EXOG+Tech rolling (100w)                       RMSE=0.05308  MAE=0.03755  DA=0.511  WDA=0.514
# --- EXOG+Macro ---
# EXOG+Macro expanding                           RMSE=0.05302  MAE=0.03804  DA=0.477  WDA=0.502
# EXOG+Macro rolling (100w)                      RMSE=0.05345  MAE=0.03790  DA=0.500  WDA=0.531
# --- EXOG+FRED_daily ---
# EXOG+FRED_daily expanding                      RMSE=0.05201  MAE=0.03750  DA=0.546  WDA=0.577
# EXOG+FRED_daily rolling (100w)                 RMSE=0.05325  MAE=0.03809  DA=0.483  WDA=0.472
# --- EXOG+COT ---
# EXOG+COT expanding                             RMSE=0.05184  MAE=0.03724  DA=0.529  WDA=0.540
# EXOG+COT rolling (100w)                        RMSE=0.05303  MAE=0.03766  DA=0.529  WDA=0.524
# --- EXOG+FRED_daily+COT ---
# EXOG+FRED_daily+COT expanding                  RMSE=0.05193  MAE=0.03736  DA=0.540  WDA=0.543
# EXOG+FRED_daily+COT rolling (100w)             RMSE=0.05298  MAE=0.03771  DA=0.540  WDA=0.558
# --- EXOG+Reddit+News ---
# EXOG+Reddit+News expanding                     RMSE=0.05244  MAE=0.03741  DA=0.534  WDA=0.555
# EXOG+Reddit+News rolling (100w)                RMSE=0.05329  MAE=0.03814  DA=0.529  WDA=0.559
# --- EXOG+Reddit ---
# EXOG+Reddit expanding                          RMSE=0.05222  MAE=0.03748  DA=0.546  WDA=0.607
# EXOG+Reddit rolling (100w)                     RMSE=0.05328  MAE=0.03794  DA=0.546  WDA=0.538
# --- EXOG+News ---
# EXOG+News expanding                            RMSE=0.05204  MAE=0.03728  DA=0.546  WDA=0.559
# EXOG+News rolling (100w)                       RMSE=0.05261  MAE=0.03754  DA=0.494  WDA=0.538
# --- EXOG+GS+Sentiment ---
# EXOG+GS+Sentiment expanding                    RMSE=0.05273  MAE=0.03727  DA=0.557  WDA=0.546
# EXOG+GS+Sentiment rolling (100w)               RMSE=0.05409  MAE=0.03785  DA=0.534  WDA=0.542
# --- EXOG+NonLin+Sentiment ---
# EXOG+NonLin+Sentiment expanding                RMSE=0.05171  MAE=0.03764  DA=0.523  WDA=0.595
# EXOG+NonLin+Sentiment rolling (100w)           RMSE=0.05307  MAE=0.03784  DA=0.489  WDA=0.541
# --- EXOG+Tech+Sentiment ---
# EXOG+Tech+Sentiment expanding                  RMSE=0.05220  MAE=0.03726  DA=0.523  WDA=0.516
# EXOG+Tech+Sentiment rolling (100w)             RMSE=0.05265  MAE=0.03742  DA=0.529  WDA=0.555
# --- EXOG+ALL ---
# EXOG+ALL expanding                             RMSE=0.05146  MAE=0.03695  DA=0.546  WDA=0.531
# EXOG+ALL rolling (100w)                        RMSE=0.05389  MAE=0.03766  DA=0.552  WDA=0.546
# --- EXOG+NewsPaid ---
# EXOG+NewsPaid expanding                        RMSE=0.05177  MAE=0.03720  DA=0.557  WDA=0.602
# EXOG+NewsPaid rolling (100w)                   RMSE=0.05269  MAE=0.03754  DA=0.494  WDA=0.521
# --- EXOG+Reddit+NewsPaid ---
# EXOG+Reddit+NewsPaid expanding                 RMSE=0.05185  MAE=0.03732  DA=0.540  WDA=0.592
# EXOG+Reddit+NewsPaid rolling (100w)            RMSE=0.05297  MAE=0.03772  DA=0.511  WDA=0.535
# --- EXOG+GS+SentimentPaid ---
# EXOG+GS+SentimentPaid expanding                RMSE=0.05174  MAE=0.03678  DA=0.563  WDA=0.574
# EXOG+GS+SentimentPaid rolling (100w)           RMSE=0.05360  MAE=0.03757  DA=0.523  WDA=0.563
# --- EXOG+NonLin+SentimentPaid ---
# EXOG+NonLin+SentimentPaid expanding            RMSE=0.05195  MAE=0.03750  DA=0.529  WDA=0.588
# EXOG+NonLin+SentimentPaid rolling (100w)       RMSE=0.05373  MAE=0.03827  DA=0.517  WDA=0.557
# --- EXOG+Tech+SentimentPaid ---
# EXOG+Tech+SentimentPaid expanding              RMSE=0.05196  MAE=0.03730  DA=0.546  WDA=0.576
# EXOG+Tech+SentimentPaid rolling (100w)         RMSE=0.05308  MAE=0.03759  DA=0.494  WDA=0.524
# --- EXOG+ALLPaid ---
# EXOG+ALLPaid expanding                         RMSE=0.05142  MAE=0.03690  DA=0.540  WDA=0.574
# EXOG+ALLPaid rolling (100w)                    RMSE=0.05329  MAE=0.03758  DA=0.563  WDA=0.585
# --- EXOG+FRED_daily+PMI ---
# EXOG+FRED_daily+PMI expanding                  RMSE=0.05199  MAE=0.03733  DA=0.557  WDA=0.593
# EXOG+FRED_daily+PMI rolling (100w)             RMSE=0.05276  MAE=0.03771  DA=0.529  WDA=0.531
# --- EXOG+FRED_daily+COT+PMI ---
# EXOG+FRED_daily+COT+PMI expanding              RMSE=0.05197  MAE=0.03735  DA=0.569  WDA=0.583
# EXOG+FRED_daily+COT+PMI rolling (100w)         RMSE=0.05329  MAE=0.03778  DA=0.523  WDA=0.544
# --- EXOG+ALL+PMI ---
# EXOG+ALL+PMI expanding                         RMSE=0.05157  MAE=0.03684  DA=0.523  WDA=0.529
# EXOG+ALL+PMI rolling (100w)                    RMSE=0.05371  MAE=0.03753  DA=0.546  WDA=0.569
# --- BestLag-All ---
# BestLag-All expanding                          RMSE=0.05229  MAE=0.03732  DA=0.552  WDA=0.562
# BestLag-All rolling (100w)                     RMSE=0.05324  MAE=0.03768  DA=0.523  WDA=0.536
# --- BestLag-Sig90 ---
# BestLag-Sig90 expanding                        RMSE=0.05211  MAE=0.03723  DA=0.546  WDA=0.572
# BestLag-Sig90 rolling (100w)                   RMSE=0.05312  MAE=0.03744  DA=0.540  WDA=0.565
# --- BestLag-Sig ---
# BestLag-Sig expanding                          RMSE=0.05236  MAE=0.03747  DA=0.534  WDA=0.546
# BestLag-Sig rolling (100w)                     RMSE=0.05256  MAE=0.03716  DA=0.569  WDA=0.579

# %% [markdown]
# ## 5. Evaluate
#
# One table — RMSE / MAE / DA / WDA for the benchmarks and every variant (both windows). **Drift
# (prevailing mean = the random-walk-with-drift floor)** is the bar the DM tests read against; `Naive`
# is a weak reference. (Weak form proper is isolated in ARIMA — the trees bundle own-history + public info.)

# %% [markdown]
# **Metrics** — RMSE / MAE (point-forecast error, magnitude), OOS R² (effect size vs Drift, shown as `r2_os` in the table below), DA / WDA (directional). Formulas, caveats, and load-bearing status: `01_arima` §5 or [`notes.md`](notes.md).

# %%
from eval_utils import oos_r2

# Naive: 1-step shift -> evaluated on y_test[1:] separately (different effective length).
naive_pred = np.concatenate([[np.nan], y_test[:-1]])   # persistence: forecast y_t with y_{t-1}
naive_m = evaluate('Naive (t-1 week)', y_test[1:], naive_pred[1:])
if naive_m: naive_m['r2_os'] = float('nan')   # different y length -- OOS R^2 not comparable

# Drift / random-walk-with-drift: expanding prevailing mean of returns observed before each test week.
_hist = list(all_w[TARGET].iloc[:n_train].values)
drift_pred = np.empty(len(y_test))
for _t, _actual in enumerate(y_test):
    drift_pred[_t] = np.mean(_hist)
    _hist.append(float(_actual))

# Drift + all variants at full test length; r2_os computed inline (0 for Drift itself).
eval_preds = {'Drift (prevailing mean)': drift_pred, **all_candidates}
main_evals = []
for name, pred in eval_preds.items():
    m = evaluate(name, y_test, pred)
    if m:
        m['r2_os'] = oos_r2(y_test, pred, drift_pred) * 100   # >0 beats the random walk OOS
        main_evals.append(m)

metrics_df = pd.DataFrame(([naive_m] if naive_m else []) + main_evals)
metrics_df = metrics_df[['model', 'rmse', 'mae', 'r2_os', 'dir_acc', 'wda']]   # r2_os next to error metrics
metrics_df.to_csv('../../../data/processed/metrics_xgboost.csv', index=False)

# Drift WDA by period (Drift's sign is always positive = the always-up line; the WDA to beat).
_yt = pd.Series(y_test, index=test_index)
print('\nDrift WDA by period (directional benchmark to beat):')
for _lbl, (_a, _b) in PERIODS.items():
    _s = _yt.loc[_a:_b]
    if len(_s):
        _au = np.sum(np.abs(_s.values) * (_s.values > 0)) / np.sum(np.abs(_s.values))
        print(f'  {_lbl:20s} WDA={_au:.3f}  (n={len(_s)})')

metrics_df
# Out:
# Naive (t-1 week)                               RMSE=0.07594  MAE=0.05397  DA=0.491  WDA=0.490
# Drift (prevailing mean)                        RMSE=0.05190  MAE=0.03714  DA=0.557  WDA=0.588
# EXOG expanding                                 RMSE=0.05194  MAE=0.03739  DA=0.529  WDA=0.580
# EXOG rolling (100w)                            RMSE=0.05319  MAE=0.03804  DA=0.506  WDA=0.524
# Tech expanding                                 RMSE=0.05202  MAE=0.03727  DA=0.529  WDA=0.542
# Tech rolling (100w)                            RMSE=0.05282  MAE=0.03739  DA=0.540  WDA=0.524
# EXOG+GS expanding                              RMSE=0.05187  MAE=0.03691  DA=0.540  WDA=0.557
# EXOG+GS rolling (100w)                         RMSE=0.05288  MAE=0.03716  DA=0.546  WDA=0.550
# EXOG+NonLin expanding                          RMSE=0.05160  MAE=0.03734  DA=0.546  WDA=0.601
# EXOG+NonLin rolling (100w)                     RMSE=0.05351  MAE=0.03828  DA=0.489  WDA=0.530
# EXOG+Tech expanding                            RMSE=0.05236  MAE=0.03741  DA=0.546  WDA=0.560
# EXOG+Tech rolling (100w)                       RMSE=0.05308  MAE=0.03755  DA=0.511  WDA=0.514
# EXOG+Macro expanding                           RMSE=0.05302  MAE=0.03804  DA=0.477  WDA=0.502
# EXOG+Macro rolling (100w)                      RMSE=0.05345  MAE=0.03790  DA=0.500  WDA=0.531
# EXOG+FRED_daily expanding                      RMSE=0.05201  MAE=0.03750  DA=0.546  WDA=0.577
# EXOG+FRED_daily rolling (100w)                 RMSE=0.05325  MAE=0.03809  DA=0.483  WDA=0.472
# EXOG+COT expanding                             RMSE=0.05184  MAE=0.03724  DA=0.529  WDA=0.540
# EXOG+COT rolling (100w)                        RMSE=0.05303  MAE=0.03766  DA=0.529  WDA=0.524
# EXOG+FRED_daily+COT expanding                  RMSE=0.05193  MAE=0.03736  DA=0.540  WDA=0.543
# EXOG+FRED_daily+COT rolling (100w)             RMSE=0.05298  MAE=0.03771  DA=0.540  WDA=0.558
# EXOG+Reddit+News expanding                     RMSE=0.05244  MAE=0.03741  DA=0.534  WDA=0.555
# EXOG+Reddit+News rolling (100w)                RMSE=0.05329  MAE=0.03814  DA=0.529  WDA=0.559
# EXOG+Reddit expanding                          RMSE=0.05222  MAE=0.03748  DA=0.546  WDA=0.607
# EXOG+Reddit rolling (100w)                     RMSE=0.05328  MAE=0.03794  DA=0.546  WDA=0.538
# EXOG+News expanding                            RMSE=0.05204  MAE=0.03728  DA=0.546  WDA=0.559
# EXOG+News rolling (100w)                       RMSE=0.05261  MAE=0.03754  DA=0.494  WDA=0.538
# EXOG+GS+Sentiment expanding                    RMSE=0.05273  MAE=0.03727  DA=0.557  WDA=0.546
# EXOG+GS+Sentiment rolling (100w)               RMSE=0.05409  MAE=0.03785  DA=0.534  WDA=0.542
# EXOG+NonLin+Sentiment expanding                RMSE=0.05171  MAE=0.03764  DA=0.523  WDA=0.595
# EXOG+NonLin+Sentiment rolling (100w)           RMSE=0.05307  MAE=0.03784  DA=0.489  WDA=0.541
# EXOG+Tech+Sentiment expanding                  RMSE=0.05220  MAE=0.03726  DA=0.523  WDA=0.516
# EXOG+Tech+Sentiment rolling (100w)             RMSE=0.05265  MAE=0.03742  DA=0.529  WDA=0.555
# EXOG+ALL expanding                             RMSE=0.05146  MAE=0.03695  DA=0.546  WDA=0.531
# EXOG+ALL rolling (100w)                        RMSE=0.05389  MAE=0.03766  DA=0.552  WDA=0.546
# EXOG+NewsPaid expanding                        RMSE=0.05177  MAE=0.03720  DA=0.557  WDA=0.602
# EXOG+NewsPaid rolling (100w)                   RMSE=0.05269  MAE=0.03754  DA=0.494  WDA=0.521
# EXOG+Reddit+NewsPaid expanding                 RMSE=0.05185  MAE=0.03732  DA=0.540  WDA=0.592
# EXOG+Reddit+NewsPaid rolling (100w)            RMSE=0.05297  MAE=0.03772  DA=0.511  WDA=0.535
# EXOG+GS+SentimentPaid expanding                RMSE=0.05174  MAE=0.03678  DA=0.563  WDA=0.574
# EXOG+GS+SentimentPaid rolling (100w)           RMSE=0.05360  MAE=0.03757  DA=0.523  WDA=0.563
# EXOG+NonLin+SentimentPaid expanding            RMSE=0.05195  MAE=0.03750  DA=0.529  WDA=0.588
# EXOG+NonLin+SentimentPaid rolling (100w)       RMSE=0.05373  MAE=0.03827  DA=0.517  WDA=0.557
# EXOG+Tech+SentimentPaid expanding              RMSE=0.05196  MAE=0.03730  DA=0.546  WDA=0.576
# EXOG+Tech+SentimentPaid rolling (100w)         RMSE=0.05308  MAE=0.03759  DA=0.494  WDA=0.524
# EXOG+ALLPaid expanding                         RMSE=0.05142  MAE=0.03690  DA=0.540  WDA=0.574
# EXOG+ALLPaid rolling (100w)                    RMSE=0.05329  MAE=0.03758  DA=0.563  WDA=0.585
# EXOG+FRED_daily+PMI expanding                  RMSE=0.05199  MAE=0.03733  DA=0.557  WDA=0.593
# EXOG+FRED_daily+PMI rolling (100w)             RMSE=0.05276  MAE=0.03771  DA=0.529  WDA=0.531
# EXOG+FRED_daily+COT+PMI expanding              RMSE=0.05197  MAE=0.03735  DA=0.569  WDA=0.583
# EXOG+FRED_daily+COT+PMI rolling (100w)         RMSE=0.05329  MAE=0.03778  DA=0.523  WDA=0.544
# EXOG+ALL+PMI expanding                         RMSE=0.05157  MAE=0.03684  DA=0.523  WDA=0.529
# EXOG+ALL+PMI rolling (100w)                    RMSE=0.05371  MAE=0.03753  DA=0.546  WDA=0.569
# BestLag-All expanding                          RMSE=0.05229  MAE=0.03732  DA=0.552  WDA=0.562
# BestLag-All rolling (100w)                     RMSE=0.05324  MAE=0.03768  DA=0.523  WDA=0.536
# BestLag-Sig90 expanding                        RMSE=0.05211  MAE=0.03723  DA=0.546  WDA=0.572
# BestLag-Sig90 rolling (100w)                   RMSE=0.05312  MAE=0.03744  DA=0.540  WDA=0.565
# BestLag-Sig expanding                          RMSE=0.05236  MAE=0.03747  DA=0.534  WDA=0.546
# BestLag-Sig rolling (100w)                     RMSE=0.05256  MAE=0.03716  DA=0.569  WDA=0.579
#
# Drift WDA by period (directional benchmark to beat):
#   2023  (choppy)       WDA=0.492  (n=52)
#   2024  (bull start)   WDA=0.570  (n=52)
#   2025  (bull run)     WDA=0.757  (n=52)
#   2026  (YTD)          WDA=0.498  (n=18)
#   ── Full test ──      WDA=0.588  (n=174)
#                                        model      rmse       mae     r2_os  \
# 0                           Naive (t-1 week)  0.075941  0.053966       NaN
# 1                    Drift (prevailing mean)  0.051902  0.037135  0.000000
# 2                             EXOG expanding  0.051937  0.037392 -0.134341
# 3                        EXOG rolling (100w)  0.053189  0.038043 -5.019678
# 4                             Tech expanding  0.052023  0.037267 -0.464897
# 5                        Tech rolling (100w)  0.052825  0.037389 -3.585420
# 6                          EXOG+GS expanding  0.051867  0.036912  0.134648
# 7                     EXOG+GS rolling (100w)  0.052876  0.037163 -3.786083
# 8                      EXOG+NonLin expanding  0.051599  0.037335  1.165541
# 9                 EXOG+NonLin rolling (100w)  0.053509  0.038280 -6.287648
# 10                       EXOG+Tech expanding  0.052364  0.037415 -1.788743
# 11                  EXOG+Tech rolling (100w)  0.053083  0.037553 -4.599830
# 12                      EXOG+Macro expanding  0.053018  0.038043 -4.344444
# 13                 EXOG+Macro rolling (100w)  0.053450  0.037895 -6.052440
# 14                 EXOG+FRED_daily expanding  0.052015  0.037503 -0.434855
# 15            EXOG+FRED_daily rolling (100w)  0.053247  0.038087 -5.250866
# 16                        EXOG+COT expanding  0.051838  0.037240  0.246458
# 17                   EXOG+COT rolling (100w)  0.053028  0.037663 -4.386884
# 18             EXOG+FRED_daily+COT expanding  0.051927  0.037363 -0.096804
# 19        EXOG+FRED_daily+COT rolling (100w)  0.052978  0.037712 -4.189073
# 20                EXOG+Reddit+News expanding  0.052445  0.037408 -2.102055
# 21           EXOG+Reddit+News rolling (100w)  0.053291  0.038135 -5.423189
# 22                     EXOG+Reddit expanding  0.052216  0.037480 -1.213622
# 23                EXOG+Reddit rolling (100w)  0.053279  0.037940 -5.375186
# 24                       EXOG+News expanding  0.052044  0.037284 -0.546867
# 25                  EXOG+News rolling (100w)  0.052611  0.037541 -2.749117
# 26               EXOG+GS+Sentiment expanding  0.052734  0.037269 -3.231808
# 27          EXOG+GS+Sentiment rolling (100w)  0.054086  0.037852 -8.593129
# 28           EXOG+NonLin+Sentiment expanding  0.051711  0.037644  0.734604
# 29      EXOG+NonLin+Sentiment rolling (100w)  0.053068  0.037839 -4.544311
# 30             EXOG+Tech+Sentiment expanding  0.052201  0.037258 -1.155236
# 31        EXOG+Tech+Sentiment rolling (100w)  0.052650  0.037422 -2.900967
# 32                        EXOG+ALL expanding  0.051463  0.036954  1.684152
# 33                   EXOG+ALL rolling (100w)  0.053889  0.037656 -7.803804
# 34                   EXOG+NewsPaid expanding  0.051772  0.037198  0.501763
# 35              EXOG+NewsPaid rolling (100w)  0.052689  0.037537 -3.052835
# 36            EXOG+Reddit+NewsPaid expanding  0.051853  0.037323  0.188179
# 37       EXOG+Reddit+NewsPaid rolling (100w)  0.052972  0.037720 -4.166193
# 38           EXOG+GS+SentimentPaid expanding  0.051737  0.036784  0.636835
# 39      EXOG+GS+SentimentPaid rolling (100w)  0.053601  0.037566 -6.654582
# 40       EXOG+NonLin+SentimentPaid expanding  0.051948  0.037496 -0.175193
# 41  EXOG+NonLin+SentimentPaid rolling (100w)  0.053731  0.038272 -7.171713
# 42         EXOG+Tech+SentimentPaid expanding  0.051965  0.037295 -0.240363
# 43    EXOG+Tech+SentimentPaid rolling (100w)  0.053079  0.037586 -4.585832
# 44                    EXOG+ALLPaid expanding  0.051424  0.036901  1.835656
# 45               EXOG+ALLPaid rolling (100w)  0.053287  0.037576 -5.407324
# 46             EXOG+FRED_daily+PMI expanding  0.051994  0.037329 -0.353497
# 47        EXOG+FRED_daily+PMI rolling (100w)  0.052764  0.037711 -3.350008
# 48         EXOG+FRED_daily+COT+PMI expanding  0.051974  0.037352 -0.274886
# 49    EXOG+FRED_daily+COT+PMI rolling (100w)  0.053291  0.037780 -5.422676
# 50                    EXOG+ALL+PMI expanding  0.051571  0.036842  1.272369
# 51               EXOG+ALL+PMI rolling (100w)  0.053711  0.037533 -7.090736
# 52                     BestLag-All expanding  0.052289  0.037319 -1.493979
# 53                BestLag-All rolling (100w)  0.053238  0.037682 -5.213117
# 54                   BestLag-Sig90 expanding  0.052112  0.037230 -0.811613
# 55              BestLag-Sig90 rolling (100w)  0.053117  0.037444 -4.733833
# 56                     BestLag-Sig expanding  0.052362  0.037468 -1.777984
# 57                BestLag-Sig rolling (100w)  0.052559  0.037162 -2.547116
#
#      dir_acc       wda
# 0   0.491329  0.489862
# 1   0.557471  0.587779
# 2   0.528736  0.580204
# 3   0.505747  0.523985
# 4   0.528736  0.542360
# 5   0.540230  0.524121
# 6   0.540230  0.556790
# 7   0.545977  0.550399
# 8   0.545977  0.601445
# 9   0.488506  0.529596
# 10  0.545977  0.559624
# 11  0.511494  0.513700
# 12  0.477011  0.502076
# 13  0.500000  0.531224
# 14  0.545977  0.577205
# 15  0.482759  0.472112
# 16  0.528736  0.539721
# 17  0.528736  0.523954
# 18  0.540230  0.542602
# 19  0.540230  0.557898
# 20  0.534483  0.555387
# 21  0.528736  0.558682
# 22  0.545977  0.607310
# 23  0.545977  0.537851
# 24  0.545977  0.558645
# 25  0.494253  0.538092
# 26  0.557471  0.546111
# 27  0.534483  0.542165
# 28  0.522989  0.594701
# 29  0.488506  0.541026
# 30  0.522989  0.515800
# 31  0.528736  0.554582
# 32  0.545977  0.531200
# 33  0.551724  0.546017
# 34  0.557471  0.601857
# 35  0.494253  0.521156
# 36  0.540230  0.592188
# 37  0.511494  0.535188
# 38  0.563218  0.574495
# 39  0.522989  0.563191
# 40  0.528736  0.588324
# 41  0.517241  0.557314
# 42  0.545977  0.575521
# 43  0.494253  0.523709
# 44  0.540230  0.573631
# 45  0.563218  0.584684
# 46  0.557471  0.593457
# 47  0.528736  0.530546
# 48  0.568966  0.582793
# 49  0.522989  0.544346
# 50  0.522989  0.529241
# 51  0.545977  0.568937
# 52  0.551724  0.562409
# 53  0.522989  0.535751
# 54  0.545977  0.572375
# 55  0.540230  0.565474
# 56  0.534483  0.546387
# 57  0.568966  0.579139

# %% [markdown]
# ## 6. Sub-period robustness + best-variant selection
#
# Pick the best variant by **RMSE** (primary, magnitude — §3a) and **WDA** (secondary, directional),
# and break each down by calendar year to check the result isn't driven by one regime.
#
# **Saved for cross-model use:** WDA-best keeps the legacy filenames (`period_xgboost_weekly.csv`,
# `preds_xgboost_best_weekly.csv`) so `evaluation.ipynb` is untouched; RMSE-best saved alongside
# (`period_xgboost_rmse_weekly.csv`, `preds_xgboost_bestrmse_weekly.csv`).

# %%
def _best_by_wda(candidates, actual):
    return max(candidates, key=lambda k:
        np.nansum(np.abs(actual) * (np.sign(actual) == np.sign(candidates[k]))) /
        np.nansum(np.abs(actual)))

def _best_by_rmse(candidates, actual):
    return min(candidates, key=lambda k:
        np.sqrt(np.nanmean((actual - candidates[k]) ** 2)))

def _period_r2(pred):
    # OOS R^2 vs Drift, per calendar sub-period (Campbell-Thompson) -- effect-size companion to
    # the per-period error metrics. Drift is the random-walk-with-drift benchmark.
    drift_s, pred_s = pd.Series(drift_pred, index=test_index), pd.Series(pred, index=test_index)
    r2 = {}
    for _lbl, (_a, _b) in PERIODS.items():
        _y  = pd.Series(y_test, index=test_index).loc[_a:_b].values
        _p  = pred_s.loc[_a:_b].values
        _d  = drift_s.loc[_a:_b].values
        if len(_y):
            r2[_lbl] = oos_r2(_y, _p, _d) * 100
    return r2

def _show_period(pred, csv=None):
    res = period_metrics(y_test, pred, test_index, PERIODS)   # RMSE / MAE / DA / WDA per period
    r2  = _period_r2(pred)
    res['R2_OS'] = [r2.get(lbl, float('nan')) for lbl in res.index]
    display(res[['n', 'RMSE', 'MAE', 'R2_OS', 'DA', 'WDA']].style
            .format({'n': '{:.0f}', 'RMSE': '{:.4f}', 'MAE': '{:.4f}', 'R2_OS': '{:+.2f}',
                     'DA': '{:.3f}', 'WDA': '{:.3f}'})
            .background_gradient(cmap='RdYlGn', subset=['DA', 'WDA'], vmin=0.4, vmax=0.7))
    if csv:
        res[['n', 'DA', 'WDA']].to_csv(csv)   # legacy schema -- evaluation.ipynb reads these

def _save_preds(pred, csv):
    pd.DataFrame({'actual': y_test, 'predicted': pred}, index=test_index) \
      .rename_axis('Date').to_csv(csv)

best_name      = _best_by_wda(all_candidates, y_test)    # WDA-best (legacy cross-model pick)
best_name_rmse = _best_by_rmse(all_candidates, y_test)
best_pred      = all_candidates[best_name]
best_pred_rmse = all_candidates[best_name_rmse]
print('Best variant -- WDA:', best_name, '|  RMSE:', best_name_rmse)

# Drift by period -- the benchmark to clear per regime.
print('\nDrift (prevailing mean) by period -- the floor:')
_show_period(drift_pred)

print('\nWDA-best by period:')
_show_period(best_pred,      '../../../data/processed/period_xgboost_weekly.csv')
print('RMSE-best by period:')
_show_period(best_pred_rmse, '../../../data/processed/period_xgboost_rmse_weekly.csv')

_save_preds(best_pred,      '../../../data/processed/preds_xgboost_best_weekly.csv')
_save_preds(best_pred_rmse, '../../../data/processed/preds_xgboost_bestrmse_weekly.csv')
print('\nSaved: period + preds (WDA-best legacy names, RMSE-best alongside).')
# Out:
# Best variant -- WDA: EXOG+Reddit expanding |  RMSE: EXOG+ALLPaid expanding
#
# Drift (prevailing mean) by period -- the floor:
# <style type="text/css">
# #T_7c387_row0_col4 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_7c387_row0_col5 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_7c387_row1_col4 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_7c387_row1_col5 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_7c387_row2_col4 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_7c387_row2_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_7c387_row3_col4 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_7c387_row3_col5 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_7c387_row4_col4 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_7c387_row4_col5 {
#   background-color: #cbe982;
#   color: #000000;
# }
# </style>
# <table id="T_7c387">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c387_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_7c387_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_7c387_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_7c387_level0_col3" class="col_heading level0 col3" >R2_OS</th>
#       <th id="T_7c387_level0_col4" class="col_heading level0 col4" >DA</th>
#       <th id="T_7c387_level0_col5" class="col_heading level0 col5" >WDA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Period</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c387_level0_row0" class="row_heading level0 row0" >2023  (choppy)</th>
#       <td id="T_7c387_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_7c387_row0_col1" class="data row0 col1" >0.0400</td>
#       <td id="T_7c387_row0_col2" class="data row0 col2" >0.0318</td>
#       <td id="T_7c387_row0_col3" class="data row0 col3" >+0.00</td>
#       <td id="T_7c387_row0_col4" class="data row0 col4" >0.481</td>
#       <td id="T_7c387_row0_col5" class="data row0 col5" >0.492</td>
#     </tr>
#     <tr>
#       <th id="T_7c387_level0_row1" class="row_heading level0 row1" >2024  (bull start)</th>
#       <td id="T_7c387_row1_col0" class="data row1 col0" >52</td>
#       <td id="T_7c387_row1_col1" class="data row1 col1" >0.0380</td>
#       <td id="T_7c387_row1_col2" class="data row1 col2" >0.0299</td>
#       <td id="T_7c387_row1_col3" class="data row1 col3" >+0.00</td>
#       <td id="T_7c387_row1_col4" class="data row1 col4" >0.500</td>
#       <td id="T_7c387_row1_col5" class="data row1 col5" >0.570</td>
#     </tr>
#     <tr>
#       <th id="T_7c387_level0_row2" class="row_heading level0 row2" >2025  (bull run)</th>
#       <td id="T_7c387_row2_col0" class="data row2 col0" >52</td>
#       <td id="T_7c387_row2_col1" class="data row2 col1" >0.0498</td>
#       <td id="T_7c387_row2_col2" class="data row2 col2" >0.0352</td>
#       <td id="T_7c387_row2_col3" class="data row2 col3" >+0.00</td>
#       <td id="T_7c387_row2_col4" class="data row2 col4" >0.692</td>
#       <td id="T_7c387_row2_col5" class="data row2 col5" >0.757</td>
#     </tr>
#     <tr>
#       <th id="T_7c387_level0_row3" class="row_heading level0 row3" >2026  (YTD)</th>
#       <td id="T_7c387_row3_col0" class="data row3 col0" >18</td>
#       <td id="T_7c387_row3_col1" class="data row3 col1" >0.1003</td>
#       <td id="T_7c387_row3_col2" class="data row3 col2" >0.0791</td>
#       <td id="T_7c387_row3_col3" class="data row3 col3" >+0.00</td>
#       <td id="T_7c387_row3_col4" class="data row3 col4" >0.556</td>
#       <td id="T_7c387_row3_col5" class="data row3 col5" >0.498</td>
#     </tr>
#     <tr>
#       <th id="T_7c387_level0_row4" class="row_heading level0 row4" >── Full test ──</th>
#       <td id="T_7c387_row4_col0" class="data row4 col0" >174</td>
#       <td id="T_7c387_row4_col1" class="data row4 col1" >0.0519</td>
#       <td id="T_7c387_row4_col2" class="data row4 col2" >0.0371</td>
#       <td id="T_7c387_row4_col3" class="data row4 col3" >+0.00</td>
#       <td id="T_7c387_row4_col4" class="data row4 col4" >0.557</td>
#       <td id="T_7c387_row4_col5" class="data row4 col5" >0.588</td>
#     </tr>
#   </tbody>
# </table>
# WDA-best by period:
# <style type="text/css">
# #T_b6d43_row0_col4 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_b6d43_row0_col5 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_b6d43_row1_col4 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_b6d43_row1_col5 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_b6d43_row2_col4 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_b6d43_row2_col5 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_b6d43_row3_col4 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_b6d43_row3_col5 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_b6d43_row4_col4 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_b6d43_row4_col5 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# </style>
# <table id="T_b6d43">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6d43_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_b6d43_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_b6d43_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_b6d43_level0_col3" class="col_heading level0 col3" >R2_OS</th>
#       <th id="T_b6d43_level0_col4" class="col_heading level0 col4" >DA</th>
#       <th id="T_b6d43_level0_col5" class="col_heading level0 col5" >WDA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Period</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6d43_level0_row0" class="row_heading level0 row0" >2023  (choppy)</th>
#       <td id="T_b6d43_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_b6d43_row0_col1" class="data row0 col1" >0.0401</td>
#       <td id="T_b6d43_row0_col2" class="data row0 col2" >0.0319</td>
#       <td id="T_b6d43_row0_col3" class="data row0 col3" >-0.32</td>
#       <td id="T_b6d43_row0_col4" class="data row0 col4" >0.481</td>
#       <td id="T_b6d43_row0_col5" class="data row0 col5" >0.537</td>
#     </tr>
#     <tr>
#       <th id="T_b6d43_level0_row1" class="row_heading level0 row1" >2024  (bull start)</th>
#       <td id="T_b6d43_row1_col0" class="data row1 col0" >52</td>
#       <td id="T_b6d43_row1_col1" class="data row1 col1" >0.0377</td>
#       <td id="T_b6d43_row1_col2" class="data row1 col2" >0.0296</td>
#       <td id="T_b6d43_row1_col3" class="data row1 col3" >+1.37</td>
#       <td id="T_b6d43_row1_col4" class="data row1 col4" >0.519</td>
#       <td id="T_b6d43_row1_col5" class="data row1 col5" >0.613</td>
#     </tr>
#     <tr>
#       <th id="T_b6d43_level0_row2" class="row_heading level0 row2" >2025  (bull run)</th>
#       <td id="T_b6d43_row2_col0" class="data row2 col0" >52</td>
#       <td id="T_b6d43_row2_col1" class="data row2 col1" >0.0506</td>
#       <td id="T_b6d43_row2_col2" class="data row2 col2" >0.0356</td>
#       <td id="T_b6d43_row2_col3" class="data row2 col3" >-3.11</td>
#       <td id="T_b6d43_row2_col4" class="data row2 col4" >0.615</td>
#       <td id="T_b6d43_row2_col5" class="data row2 col5" >0.629</td>
#     </tr>
#     <tr>
#       <th id="T_b6d43_level0_row3" class="row_heading level0 row3" >2026  (YTD)</th>
#       <td id="T_b6d43_row3_col0" class="data row3 col0" >18</td>
#       <td id="T_b6d43_row3_col1" class="data row3 col1" >0.1010</td>
#       <td id="T_b6d43_row3_col2" class="data row3 col2" >0.0820</td>
#       <td id="T_b6d43_row3_col3" class="data row3 col3" >-1.34</td>
#       <td id="T_b6d43_row3_col4" class="data row3 col4" >0.611</td>
#       <td id="T_b6d43_row3_col5" class="data row3 col5" >0.654</td>
#     </tr>
#     <tr>
#       <th id="T_b6d43_level0_row4" class="row_heading level0 row4" >── Full test ──</th>
#       <td id="T_b6d43_row4_col0" class="data row4 col0" >174</td>
#       <td id="T_b6d43_row4_col1" class="data row4 col1" >0.0522</td>
#       <td id="T_b6d43_row4_col2" class="data row4 col2" >0.0375</td>
#       <td id="T_b6d43_row4_col3" class="data row4 col3" >-1.21</td>
#       <td id="T_b6d43_row4_col4" class="data row4 col4" >0.546</td>
#       <td id="T_b6d43_row4_col5" class="data row4 col5" >0.607</td>
#     </tr>
#   </tbody>
# </table>
# RMSE-best by period:
# <style type="text/css">
# #T_b85df_row0_col4 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_b85df_row0_col5 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_b85df_row1_col4 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_b85df_row1_col5 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_b85df_row2_col4 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_b85df_row2_col5 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_b85df_row3_col4 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_b85df_row3_col5 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_b85df_row4_col4 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_b85df_row4_col5 {
#   background-color: #e0f295;
#   color: #000000;
# }
# </style>
# <table id="T_b85df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b85df_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_b85df_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_b85df_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_b85df_level0_col3" class="col_heading level0 col3" >R2_OS</th>
#       <th id="T_b85df_level0_col4" class="col_heading level0 col4" >DA</th>
#       <th id="T_b85df_level0_col5" class="col_heading level0 col5" >WDA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Period</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b85df_level0_row0" class="row_heading level0 row0" >2023  (choppy)</th>
#       <td id="T_b85df_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_b85df_row0_col1" class="data row0 col1" >0.0400</td>
#       <td id="T_b85df_row0_col2" class="data row0 col2" >0.0319</td>
#       <td id="T_b85df_row0_col3" class="data row0 col3" >+0.25</td>
#       <td id="T_b85df_row0_col4" class="data row0 col4" >0.462</td>
#       <td id="T_b85df_row0_col5" class="data row0 col5" >0.452</td>
#     </tr>
#     <tr>
#       <th id="T_b85df_level0_row1" class="row_heading level0 row1" >2024  (bull start)</th>
#       <td id="T_b85df_row1_col0" class="data row1 col0" >52</td>
#       <td id="T_b85df_row1_col1" class="data row1 col1" >0.0369</td>
#       <td id="T_b85df_row1_col2" class="data row1 col2" >0.0294</td>
#       <td id="T_b85df_row1_col3" class="data row1 col3" >+5.81</td>
#       <td id="T_b85df_row1_col4" class="data row1 col4" >0.558</td>
#       <td id="T_b85df_row1_col5" class="data row1 col5" >0.640</td>
#     </tr>
#     <tr>
#       <th id="T_b85df_level0_row2" class="row_heading level0 row2" >2025  (bull run)</th>
#       <td id="T_b85df_row2_col0" class="data row2 col0" >52</td>
#       <td id="T_b85df_row2_col1" class="data row2 col1" >0.0492</td>
#       <td id="T_b85df_row2_col2" class="data row2 col2" >0.0340</td>
#       <td id="T_b85df_row2_col3" class="data row2 col3" >+2.47</td>
#       <td id="T_b85df_row2_col4" class="data row2 col4" >0.596</td>
#       <td id="T_b85df_row2_col5" class="data row2 col5" >0.632</td>
#     </tr>
#     <tr>
#       <th id="T_b85df_level0_row3" class="row_heading level0 row3" >2026  (YTD)</th>
#       <td id="T_b85df_row3_col0" class="data row3 col0" >18</td>
#       <td id="T_b85df_row3_col1" class="data row3 col1" >0.1001</td>
#       <td id="T_b85df_row3_col2" class="data row3 col2" >0.0815</td>
#       <td id="T_b85df_row3_col3" class="data row3 col3" >+0.47</td>
#       <td id="T_b85df_row3_col4" class="data row3 col4" >0.556</td>
#       <td id="T_b85df_row3_col5" class="data row3 col5" >0.566</td>
#     </tr>
#     <tr>
#       <th id="T_b85df_level0_row4" class="row_heading level0 row4" >── Full test ──</th>
#       <td id="T_b85df_row4_col0" class="data row4 col0" >174</td>
#       <td id="T_b85df_row4_col1" class="data row4 col1" >0.0514</td>
#       <td id="T_b85df_row4_col2" class="data row4 col2" >0.0369</td>
#       <td id="T_b85df_row4_col3" class="data row4 col3" >+1.84</td>
#       <td id="T_b85df_row4_col4" class="data row4 col4" >0.540</td>
#       <td id="T_b85df_row4_col5" class="data row4 col5" >0.574</td>
#     </tr>
#   </tbody>
# </table>
# Saved: period + preds (WDA-best legacy names, RMSE-best alongside).

# %% [markdown]
# ## 7. Predicted vs actual — best variant vs drift
#
# Full test window, **two panels**: top = WDA-best (directional pick), bottom = RMSE-best (magnitude
# pick — the timid variant nearest the drift). The drift floor is overlaid so each variant's lift (or
# lack of it) is visible.

# %%
fig, axes = plt.subplots(2, 1, figsize=(13, 8), sharex=True)
panels = [('WDA-best', best_name, best_pred), ('RMSE-best', best_name_rmse, best_pred_rmse)]
for ax, (tag, vname, vpred) in zip(axes, panels):
    ax.plot(test_index, y_test,     label='Actual',        lw=1,   color='black')
    ax.plot(test_index, drift_pred, label='Drift (floor)', lw=1.2, ls=':', color='seagreen')
    ax.plot(test_index, vpred,      label=vname,           lw=1.1, alpha=0.85, color='#e67e22')
    ax.axhline(0, color='grey', lw=0.5, ls='--')
    ax.set_title(f'XGBoost weekly forecast -- {tag} vs drift')
    ax.set_ylabel('Weekly log-return')
    ax.legend(fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Significance tests
#
# The descriptive metrics in §5 rank the models; this section asks whether the differences are
# **statistically real**. All tests are vs the **Drift** floor (prevailing mean = random walk).
# Trees bundle own-history + public info, so this is a **semi-strong** test (weak form proper is
# isolated in ARIMA). Effect size (OOS R²) is already in the §5 table; DM below supplies its
# significance. Full definitions and Newey–West detail: `01_arima` §8 and [`notes.md`](notes.md).
#
# | Test | Asks | Axis | Role |
# |---|---|---|---|
# | **DM — squared error** | Does *any* variant beat the random walk? | magnitude | **load-bearing** |
# | **DM — absolute error** | …and does that survive heavy tails? | magnitude | robustness |
# | **Pesaran–Timmermann** (§8b) | Do the *sign* calls beat chance? | direction | secondary |
#
# **Sign convention:** `pred1` = Drift always. $d_t = \text{loss}(\text{Drift}) - \text{loss}(\text{model})$,
# so **positive** DM = model beats Drift (evidence against efficiency); **negative** = Drift wins.

# %% [markdown]
# ### DM — squared-error floor (load-bearing)
#
# The headline efficiency test: does any variant produce significantly lower **squared** forecast
# errors than the Drift? This is the proper significance test for the OOS R² in §5 — both are
# MSFE-based, so DM is internally consistent with the effect size already shown.

# %%
# Semi-strong floor [PRIMARY] — squared-error loss vs Drift.
# DM is the significance test for the OOS R^2 in §5 (both MSFE-based).
print("Diebold-Mariano -- vs Drift floor   [squared error]")
print("Semi-strong test: can any variant beat the no-predictability drift?")
print("-" * 90)
for name, pred in all_candidates.items():
    diebold_mariano(y_test, drift_pred, pred, "Drift", name)
# Out:
# Diebold-Mariano -- vs Drift floor   [squared error]
# Semi-strong test: can any variant beat the no-predictability drift?
# ------------------------------------------------------------------------------------------
# Drift                                    vs EXOG expanding                            DM=-0.193  p=0.847  (ns)  -> winner: tie
# Drift                                    vs EXOG rolling (100w)                       DM=-1.860  p=0.063  (ns)  -> winner: tie
# Drift                                    vs Tech expanding                            DM=-0.154  p=0.878  (ns)  -> winner: tie
# Drift                                    vs Tech rolling (100w)                       DM=-0.636  p=0.525  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS expanding                         DM=+0.107  p=0.915  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS rolling (100w)                    DM=-0.765  p=0.444  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin expanding                     DM=+0.608  p=0.543  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin rolling (100w)                DM=-1.926  p=0.054  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech expanding                       DM=-0.615  p=0.538  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech rolling (100w)                  DM=-0.798  p=0.425  (ns)  -> winner: tie
# Drift                                    vs EXOG+Macro expanding                      DM=-1.097  p=0.273  (ns)  -> winner: tie
# Drift                                    vs EXOG+Macro rolling (100w)                 DM=-1.020  p=0.308  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily expanding                 DM=-0.656  p=0.512  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily rolling (100w)            DM=-2.082  p=0.037  *     -> winner: Drift
# Drift                                    vs EXOG+COT expanding                        DM=+0.284  p=0.776  (ns)  -> winner: tie
# Drift                                    vs EXOG+COT rolling (100w)                   DM=-1.079  p=0.281  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT expanding             DM=-0.164  p=0.869  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT rolling (100w)        DM=-1.124  p=0.261  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+News expanding                DM=-0.821  p=0.411  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+News rolling (100w)           DM=-2.095  p=0.036  *     -> winner: Drift
# Drift                                    vs EXOG+Reddit expanding                     DM=-1.028  p=0.304  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit rolling (100w)                DM=-2.099  p=0.036  *     -> winner: Drift
# Drift                                    vs EXOG+News expanding                       DM=-0.374  p=0.708  (ns)  -> winner: tie
# Drift                                    vs EXOG+News rolling (100w)                  DM=-1.143  p=0.253  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+Sentiment expanding               DM=-0.860  p=0.390  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+Sentiment rolling (100w)          DM=-1.312  p=0.190  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+Sentiment expanding           DM=+0.321  p=0.748  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+Sentiment rolling (100w)      DM=-1.470  p=0.142  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+Sentiment expanding             DM=-0.355  p=0.723  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+Sentiment rolling (100w)        DM=-0.558  p=0.577  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL expanding                        DM=+0.347  p=0.728  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL rolling (100w)                   DM=-1.097  p=0.273  (ns)  -> winner: tie
# Drift                                    vs EXOG+NewsPaid expanding                   DM=+0.562  p=0.574  (ns)  -> winner: tie
# Drift                                    vs EXOG+NewsPaid rolling (100w)              DM=-1.081  p=0.280  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+NewsPaid expanding            DM=+0.179  p=0.858  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+NewsPaid rolling (100w)       DM=-1.361  p=0.173  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+SentimentPaid expanding           DM=+0.349  p=0.727  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+SentimentPaid rolling (100w)      DM=-1.045  p=0.296  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+SentimentPaid expanding       DM=-0.055  p=0.956  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+SentimentPaid rolling (100w)  DM=-1.740  p=0.082  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+SentimentPaid expanding         DM=-0.080  p=0.936  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+SentimentPaid rolling (100w)    DM=-0.739  p=0.460  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALLPaid expanding                    DM=+0.786  p=0.432  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALLPaid rolling (100w)               DM=-0.844  p=0.399  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+PMI expanding             DM=-0.536  p=0.592  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+PMI rolling (100w)        DM=-1.338  p=0.181  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT+PMI expanding         DM=-0.401  p=0.688  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT+PMI rolling (100w)    DM=-1.265  p=0.206  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL+PMI expanding                    DM=+0.242  p=0.809  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL+PMI rolling (100w)               DM=-0.988  p=0.323  (ns)  -> winner: tie
# Drift                                    vs BestLag-All expanding                     DM=-0.442  p=0.659  (ns)  -> winner: tie
# Drift                                    vs BestLag-All rolling (100w)                DM=-0.901  p=0.368  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig90 expanding                   DM=-0.433  p=0.665  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig90 rolling (100w)              DM=-0.835  p=0.404  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig expanding                     DM=-0.688  p=0.492  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig rolling (100w)                DM=-0.495  p=0.620  (ns)  -> winner: tie

# %% [markdown]
# ### DM — absolute-error (robustness)
#
# Same framework, loss $\lvert y-\hat y\rvert$ instead of $(y-\hat y)^2$. Weekly silver returns
# are heavy-tailed — a few outlier weeks (squeeze, COVID, 2025 bull leg) dominate squared loss.
# Absolute-error checks whether the result survives a less outlier-sensitive criterion. Squared
# error stays the headline.

# %%
# Robustness -- floor test under ABSOLUTE-error loss.
print("Diebold-Mariano -- vs Drift floor   [absolute-error loss, robustness]")
print("-" * 90)
for name, pred in all_candidates.items():
    diebold_mariano(y_test, drift_pred, pred, "Drift", name, loss='ae')
# Out:
# Diebold-Mariano -- vs Drift floor   [absolute-error loss, robustness]
# ------------------------------------------------------------------------------------------
# Drift                                    vs EXOG expanding                            DM=-1.003  p=0.316  (ns)  -> winner: tie
# Drift                                    vs EXOG rolling (100w)                       DM=-1.603  p=0.109  (ns)  -> winner: tie
# Drift                                    vs Tech expanding                            DM=-0.256  p=0.798  (ns)  -> winner: tie
# Drift                                    vs Tech rolling (100w)                       DM=-0.262  p=0.794  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS expanding                         DM=+0.736  p=0.462  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS rolling (100w)                    DM=-0.032  p=0.974  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin expanding                     DM=-0.664  p=0.507  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin rolling (100w)                DM=-1.646  p=0.100  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech expanding                       DM=-0.595  p=0.552  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech rolling (100w)                  DM=-0.464  p=0.643  (ns)  -> winner: tie
# Drift                                    vs EXOG+Macro expanding                      DM=-1.337  p=0.181  (ns)  -> winner: tie
# Drift                                    vs EXOG+Macro rolling (100w)                 DM=-0.767  p=0.443  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily expanding                 DM=-1.303  p=0.193  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily rolling (100w)            DM=-1.699  p=0.089  (ns)  -> winner: tie
# Drift                                    vs EXOG+COT expanding                        DM=-0.404  p=0.686  (ns)  -> winner: tie
# Drift                                    vs EXOG+COT rolling (100w)                   DM=-0.761  p=0.446  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT expanding             DM=-0.980  p=0.327  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT rolling (100w)        DM=-0.849  p=0.396  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+News expanding                DM=-0.622  p=0.534  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+News rolling (100w)           DM=-1.743  p=0.081  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit expanding                     DM=-1.116  p=0.264  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit rolling (100w)                DM=-1.367  p=0.172  (ns)  -> winner: tie
# Drift                                    vs EXOG+News expanding                       DM=-0.444  p=0.657  (ns)  -> winner: tie
# Drift                                    vs EXOG+News rolling (100w)                  DM=-0.758  p=0.449  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+Sentiment expanding               DM=-0.247  p=0.805  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+Sentiment rolling (100w)          DM=-0.620  p=0.535  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+Sentiment expanding           DM=-1.353  p=0.176  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+Sentiment rolling (100w)      DM=-1.070  p=0.285  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+Sentiment expanding             DM=-0.229  p=0.819  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+Sentiment rolling (100w)        DM=-0.318  p=0.750  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL expanding                        DM=+0.204  p=0.839  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL rolling (100w)                   DM=-0.447  p=0.655  (ns)  -> winner: tie
# Drift                                    vs EXOG+NewsPaid expanding                   DM=-0.256  p=0.798  (ns)  -> winner: tie
# Drift                                    vs EXOG+NewsPaid rolling (100w)              DM=-0.705  p=0.481  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+NewsPaid expanding            DM=-0.762  p=0.446  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+NewsPaid rolling (100w)       DM=-1.065  p=0.287  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+SentimentPaid expanding           DM=+0.904  p=0.366  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+SentimentPaid rolling (100w)      DM=-0.424  p=0.671  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+SentimentPaid expanding       DM=-0.665  p=0.506  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+SentimentPaid rolling (100w)  DM=-1.381  p=0.167  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+SentimentPaid expanding         DM=-0.303  p=0.762  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+SentimentPaid rolling (100w)    DM=-0.465  p=0.642  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALLPaid expanding                    DM=+0.519  p=0.604  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALLPaid rolling (100w)               DM=-0.476  p=0.634  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+PMI expanding             DM=-0.842  p=0.400  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+PMI rolling (100w)        DM=-1.044  p=0.296  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT+PMI expanding         DM=-0.955  p=0.339  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT+PMI rolling (100w)    DM=-0.881  p=0.378  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL+PMI expanding                    DM=+0.306  p=0.759  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL+PMI rolling (100w)               DM=-0.320  p=0.749  (ns)  -> winner: tie
# Drift                                    vs BestLag-All expanding                     DM=-0.359  p=0.720  (ns)  -> winner: tie
# Drift                                    vs BestLag-All rolling (100w)                DM=-0.612  p=0.541  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig90 expanding                   DM=-0.289  p=0.772  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig90 rolling (100w)              DM=-0.333  p=0.739  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig expanding                     DM=-0.795  p=0.427  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig rolling (100w)                DM=-0.027  p=0.978  (ns)  -> winner: tie

# %% [markdown]
# ## 8b. Directional test — Pesaran–Timmermann (secondary lens)
#
# DM is a *magnitude* test; DA/WDA are *directional*, so their significance needs **Pesaran–
# Timmermann (1992)** — H0: predicted & actual signs independent (base-rate aware; *degenerate*
# for a constant-sign forecast like the drift). **Secondary** to the DM-vs-Drift magnitude
# verdict. Run across all variants to size the selection / multiple-testing picture.

# %%
from eval_utils import pesaran_timmermann

print("Pesaran-Timmermann directional test — full test window")
print("H0: predicted & actual signs independent  |  * p<0.05  ** p<0.01  *** p<0.001")
print("-" * 90)
pesaran_timmermann(y_test, drift_pred, name="Drift (always-up)")   # degenerate ref
pt_results = {n: pesaran_timmermann(y_test, p, name=n) for n, p in all_candidates.items()}
_tested = [r for r in pt_results.values() if not np.isnan(r['p'])]
_sig    = {n: r for n, r in pt_results.items() if not np.isnan(r['p']) and r['p'] < 0.05}
print(f"\n{len(_sig)}/{len(_tested)} variants significant at p<0.05 "
      f"(~{0.05 * len(_tested):.1f} expected by chance): {list(_sig)}")

print(f"\nPer-period PT — {best_name}:")
_yt = pd.Series(y_test, index=test_index)
_bp = pd.Series(best_pred, index=test_index)
for _lbl, (_a, _b) in PERIODS.items():
    _yy = _yt.loc[_a:_b].values
    _pp = _bp.loc[_a:_b].values
    if len(_yy) >= 12:
        pesaran_timmermann(_yy, _pp, name=f"  {_lbl}  (n={len(_yy)})")
# Out:
# Pesaran-Timmermann directional test — full test window
# H0: predicted & actual signs independent  |  * p<0.05  ** p<0.01  *** p<0.001
# ------------------------------------------------------------------------------------------
# Drift (always-up)                         DA=0.557  DA|indep=0.557  PT degenerate (constant-sign forecast)  -> winner: n/a
# EXOG expanding                            DA=0.529  DA|indep=0.542  PT=-0.532  p=0.594  (ns)  -> winner: tie (chance)
# EXOG rolling (100w)                       DA=0.506  DA|indep=0.517  PT=-0.319  p=0.750  (ns)  -> winner: tie (chance)
# Tech expanding                            DA=0.529  DA|indep=0.537  PT=-0.287  p=0.774  (ns)  -> winner: tie (chance)
# Tech rolling (100w)                       DA=0.540  DA|indep=0.499  PT=+1.107  p=0.268  (ns)  -> winner: tie (chance)
# EXOG+GS expanding                         DA=0.540  DA|indep=0.542  PT=-0.081  p=0.936  (ns)  -> winner: tie (chance)
# EXOG+GS rolling (100w)                    DA=0.546  DA|indep=0.522  PT=+0.696  p=0.486  (ns)  -> winner: tie (chance)
# EXOG+NonLin expanding                     DA=0.546  DA|indep=0.544  PT=+0.072  p=0.943  (ns)  -> winner: tie (chance)
# EXOG+NonLin rolling (100w)                DA=0.489  DA|indep=0.517  PT=-0.779  p=0.436  (ns)  -> winner: tie (chance)
# EXOG+Tech expanding                       DA=0.546  DA|indep=0.542  PT=+0.168  p=0.866  (ns)  -> winner: tie (chance)
# EXOG+Tech rolling (100w)                  DA=0.511  DA|indep=0.501  PT=+0.289  p=0.773  (ns)  -> winner: tie (chance)
# EXOG+Macro expanding                      DA=0.477  DA|indep=0.535  PT=-1.948  p=0.051  (ns)  -> winner: tie (chance)
# EXOG+Macro rolling (100w)                 DA=0.500  DA|indep=0.526  PT=-0.768  p=0.443  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily expanding                 DA=0.546  DA|indep=0.542  PT=+0.168  p=0.866  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily rolling (100w)            DA=0.483  DA|indep=0.511  PT=-0.754  p=0.451  (ns)  -> winner: tie (chance)
# EXOG+COT expanding                        DA=0.529  DA|indep=0.540  PT=-0.401  p=0.688  (ns)  -> winner: tie (chance)
# EXOG+COT rolling (100w)                   DA=0.529  DA|indep=0.516  PT=+0.357  p=0.721  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+COT expanding             DA=0.540  DA|indep=0.541  PT=-0.028  p=0.978  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+COT rolling (100w)        DA=0.540  DA|indep=0.517  PT=+0.643  p=0.520  (ns)  -> winner: tie (chance)
# EXOG+Reddit+News expanding                DA=0.534  DA|indep=0.540  PT=-0.217  p=0.828  (ns)  -> winner: tie (chance)
# EXOG+Reddit+News rolling (100w)           DA=0.529  DA|indep=0.520  PT=+0.253  p=0.800  (ns)  -> winner: tie (chance)
# EXOG+Reddit expanding                     DA=0.546  DA|indep=0.534  PT=+0.404  p=0.686  (ns)  -> winner: tie (chance)
# EXOG+Reddit rolling (100w)                DA=0.546  DA|indep=0.515  PT=+0.850  p=0.395  (ns)  -> winner: tie (chance)
# EXOG+News expanding                       DA=0.546  DA|indep=0.539  PT=+0.254  p=0.800  (ns)  -> winner: tie (chance)
# EXOG+News rolling (100w)                  DA=0.494  DA|indep=0.521  PT=-0.770  p=0.441  (ns)  -> winner: tie (chance)
# EXOG+GS+Sentiment expanding               DA=0.557  DA|indep=0.532  PT=+0.809  p=0.418  (ns)  -> winner: tie (chance)
# EXOG+GS+Sentiment rolling (100w)          DA=0.534  DA|indep=0.518  PT=+0.466  p=0.641  (ns)  -> winner: tie (chance)
# EXOG+NonLin+Sentiment expanding           DA=0.523  DA|indep=0.542  PT=-0.719  p=0.472  (ns)  -> winner: tie (chance)
# EXOG+NonLin+Sentiment rolling (100w)      DA=0.489  DA|indep=0.523  PT=-1.007  p=0.314  (ns)  -> winner: tie (chance)
# EXOG+Tech+Sentiment expanding             DA=0.523  DA|indep=0.527  PT=-0.124  p=0.902  (ns)  -> winner: tie (chance)
# EXOG+Tech+Sentiment rolling (100w)        DA=0.529  DA|indep=0.508  PT=+0.560  p=0.576  (ns)  -> winner: tie (chance)
# EXOG+ALL expanding                        DA=0.546  DA|indep=0.526  PT=+0.602  p=0.547  (ns)  -> winner: tie (chance)
# EXOG+ALL rolling (100w)                   DA=0.552  DA|indep=0.517  PT=+0.964  p=0.335  (ns)  -> winner: tie (chance)
# EXOG+NewsPaid expanding                   DA=0.557  DA|indep=0.527  PT=+0.918  p=0.359  (ns)  -> winner: tie (chance)
# EXOG+NewsPaid rolling (100w)              DA=0.494  DA|indep=0.518  PT=-0.682  p=0.495  (ns)  -> winner: tie (chance)
# EXOG+Reddit+NewsPaid expanding            DA=0.540  DA|indep=0.537  PT=+0.113  p=0.910  (ns)  -> winner: tie (chance)
# EXOG+Reddit+NewsPaid rolling (100w)       DA=0.511  DA|indep=0.517  PT=-0.140  p=0.889  (ns)  -> winner: tie (chance)
# EXOG+GS+SentimentPaid expanding           DA=0.563  DA|indep=0.538  PT=+0.890  p=0.374  (ns)  -> winner: tie (chance)
# EXOG+GS+SentimentPaid rolling (100w)      DA=0.523  DA|indep=0.517  PT=+0.180  p=0.857  (ns)  -> winner: tie (chance)
# EXOG+NonLin+SentimentPaid expanding       DA=0.529  DA|indep=0.526  PT=+0.069  p=0.945  (ns)  -> winner: tie (chance)
# EXOG+NonLin+SentimentPaid rolling (100w)  DA=0.517  DA|indep=0.524  PT=-0.191  p=0.848  (ns)  -> winner: tie (chance)
# EXOG+Tech+SentimentPaid expanding         DA=0.546  DA|indep=0.539  PT=+0.254  p=0.800  (ns)  -> winner: tie (chance)
# EXOG+Tech+SentimentPaid rolling (100w)    DA=0.494  DA|indep=0.504  PT=-0.259  p=0.795  (ns)  -> winner: tie (chance)
# EXOG+ALLPaid expanding                    DA=0.540  DA|indep=0.546  PT=-0.270  p=0.787  (ns)  -> winner: tie (chance)
# EXOG+ALLPaid rolling (100w)               DA=0.563  DA|indep=0.521  PT=+1.205  p=0.228  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+PMI expanding             DA=0.557  DA|indep=0.535  PT=+0.754  p=0.451  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+PMI rolling (100w)        DA=0.529  DA|indep=0.516  PT=+0.357  p=0.721  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+COT+PMI expanding         DA=0.569  DA|indep=0.543  PT=+1.043  p=0.297  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+COT+PMI rolling (100w)    DA=0.523  DA|indep=0.518  PT=+0.144  p=0.885  (ns)  -> winner: tie (chance)
# EXOG+ALL+PMI expanding                    DA=0.523  DA|indep=0.524  PT=-0.043  p=0.966  (ns)  -> winner: tie (chance)
# EXOG+ALL+PMI rolling (100w)               DA=0.546  DA|indep=0.518  PT=+0.788  p=0.430  (ns)  -> winner: tie (chance)
# BestLag-All expanding                     DA=0.552  DA|indep=0.522  PT=+0.847  p=0.397  (ns)  -> winner: tie (chance)
# BestLag-All rolling (100w)                DA=0.523  DA|indep=0.526  PT=-0.083  p=0.934  (ns)  -> winner: tie (chance)
# BestLag-Sig90 expanding                   DA=0.546  DA|indep=0.538  PT=+0.293  p=0.769  (ns)  -> winner: tie (chance)
# BestLag-Sig90 rolling (100w)              DA=0.540  DA|indep=0.521  PT=+0.547  p=0.585  (ns)  -> winner: tie (chance)
# BestLag-Sig expanding                     DA=0.534  DA|indep=0.542  PT=-0.276  p=0.783  (ns)  -> winner: tie (chance)
# BestLag-Sig rolling (100w)                DA=0.569  DA|indep=0.522  PT=+1.358  p=0.175  (ns)  -> winner: tie (chance)
#
# 0/56 variants significant at p<0.05 (~2.8 expected by chance): []
#
# Per-period PT — EXOG+Reddit expanding:
#   2023  (choppy)  (n=52)                  DA=0.481  DA|indep=0.490  PT=-0.154  p=0.878  (ns)  -> winner: tie (chance)
#   2024  (bull start)  (n=52)              DA=0.519  DA|indep=0.500  PT=+0.343  p=0.732  (ns)  -> winner: tie (chance)
#   2025  (bull run)  (n=52)                DA=0.615  DA|indep=0.618  PT=-0.059  p=0.953  (ns)  -> winner: tie (chance)
#   2026  (YTD)  (n=18)                     DA=0.611  DA|indep=0.537  PT=+0.873  p=0.383  (ns)  -> winner: tie (chance)
#   ── Full test ──  (n=174)                DA=0.546  DA|indep=0.534  PT=+0.404  p=0.686  (ns)  -> winner: tie (chance)

# %% [markdown]
# ## 8c. Robustness — drop the 2025 bull run (full battery)
#
# 2025 carries the entire always-up line, so once the full-window tests are done, re-run **the whole
# battery** — metrics + OOS R² + DM floor (se/ae) + PT — on **2023 + 2024 + 2026** only. Evaluation-only
# (models unchanged, still trained walk-forward through 2025); pooled (per-year DM is underpowered). The
# efficiency conclusion *strengthens* once the bull is removed.

# %%
from eval_utils import pesaran_timmermann
# Full battery on the non-bull window. Evaluation-only (forecasts unchanged); pooled for DM power.
mask_ex25 = np.asarray(test_index.year != 2025)
a_ex      = y_test[mask_ex25]
drift_ex  = drift_pred[mask_ex25]
au_ex     = np.sum(np.abs(a_ex) * (a_ex > 0)) / np.sum(np.abs(a_ex))
print(f'Ex-2025 sample: {int(mask_ex25.sum())} weeks  |  always-up WDA = {au_ex:.3f}')

print('\nMetrics (2025 excluded) -- RMSE / MAE / DA / WDA:')
evaluate('Drift (prevailing mean)', a_ex, drift_ex)
for name, pred in all_candidates.items():
    evaluate(name, a_ex, np.asarray(pred)[mask_ex25])

print('\nOOS R^2 vs Drift (2025 excluded) -- >0 beats the random walk:')
print('-' * 90)
for name, pred in all_candidates.items():
    _r2 = oos_r2(a_ex, np.asarray(pred)[mask_ex25], drift_ex) * 100
    print(f'  {name:40s} R2_OS = {_r2:+6.2f}%   -> winner: {name if _r2 > 0 else "Drift"}')

print('\nDM -- vs Drift floor, 2025 excluded [squared error]:')
print('-' * 90)
for name, pred in all_candidates.items():
    diebold_mariano(a_ex, drift_ex, np.asarray(pred)[mask_ex25], 'Drift', name)

print('\nDM -- vs Drift floor, 2025 excluded [absolute-error loss, robustness]:')
print('-' * 90)
for name, pred in all_candidates.items():
    diebold_mariano(a_ex, drift_ex, np.asarray(pred)[mask_ex25], 'Drift', name, loss='ae')

print('\nPesaran-Timmermann (2025 excluded) -- directional sign test:')
print('-' * 90)
for name, pred in all_candidates.items():
    pesaran_timmermann(a_ex, np.asarray(pred)[mask_ex25], name=name)
# Out:
# Ex-2025 sample: 122 weeks  |  always-up WDA = 0.520
#
# Metrics (2025 excluded) -- RMSE / MAE / DA / WDA:
# Drift (prevailing mean)                        RMSE=0.05275  MAE=0.03796  DA=0.500  WDA=0.520
# EXOG expanding                                 RMSE=0.05270  MAE=0.03825  DA=0.492  WDA=0.555
# EXOG rolling (100w)                            RMSE=0.05411  MAE=0.03896  DA=0.484  WDA=0.476
# Tech expanding                                 RMSE=0.05251  MAE=0.03799  DA=0.508  WDA=0.571
# Tech rolling (100w)                            RMSE=0.05431  MAE=0.03831  DA=0.557  WDA=0.517
# EXOG+GS expanding                              RMSE=0.05286  MAE=0.03804  DA=0.516  WDA=0.520
# EXOG+GS rolling (100w)                         RMSE=0.05423  MAE=0.03851  DA=0.508  WDA=0.503
# EXOG+NonLin expanding                          RMSE=0.05232  MAE=0.03836  DA=0.500  WDA=0.567
# EXOG+NonLin rolling (100w)                     RMSE=0.05474  MAE=0.03929  DA=0.475  WDA=0.478
# EXOG+Tech expanding                            RMSE=0.05316  MAE=0.03826  DA=0.500  WDA=0.538
# EXOG+Tech rolling (100w)                       RMSE=0.05442  MAE=0.03829  DA=0.500  WDA=0.449
# EXOG+Macro expanding                           RMSE=0.05422  MAE=0.03907  DA=0.443  WDA=0.459
# EXOG+Macro rolling (100w)                      RMSE=0.05524  MAE=0.03943  DA=0.467  WDA=0.505
# EXOG+FRED_daily expanding                      RMSE=0.05279  MAE=0.03832  DA=0.508  WDA=0.540
# EXOG+FRED_daily rolling (100w)                 RMSE=0.05439  MAE=0.03919  DA=0.459  WDA=0.407
# EXOG+COT expanding                             RMSE=0.05259  MAE=0.03810  DA=0.492  WDA=0.498
# EXOG+COT rolling (100w)                        RMSE=0.05456  MAE=0.03891  DA=0.500  WDA=0.482
# EXOG+FRED_daily+COT expanding                  RMSE=0.05267  MAE=0.03811  DA=0.508  WDA=0.502
# EXOG+FRED_daily+COT rolling (100w)             RMSE=0.05459  MAE=0.03903  DA=0.525  WDA=0.521
# EXOG+Reddit+News expanding                     RMSE=0.05353  MAE=0.03845  DA=0.492  WDA=0.515
# EXOG+Reddit+News rolling (100w)                RMSE=0.05435  MAE=0.03922  DA=0.508  WDA=0.516
# EXOG+Reddit expanding                          RMSE=0.05288  MAE=0.03830  DA=0.516  WDA=0.599
# EXOG+Reddit rolling (100w)                     RMSE=0.05435  MAE=0.03887  DA=0.557  WDA=0.533
# EXOG+News expanding                            RMSE=0.05288  MAE=0.03813  DA=0.492  WDA=0.510
# EXOG+News rolling (100w)                       RMSE=0.05383  MAE=0.03870  DA=0.467  WDA=0.488
# EXOG+GS+Sentiment expanding                    RMSE=0.05381  MAE=0.03828  DA=0.541  WDA=0.531
# EXOG+GS+Sentiment rolling (100w)               RMSE=0.05547  MAE=0.03904  DA=0.516  WDA=0.501
# EXOG+NonLin+Sentiment expanding                RMSE=0.05250  MAE=0.03863  DA=0.492  WDA=0.572
# EXOG+NonLin+Sentiment rolling (100w)           RMSE=0.05446  MAE=0.03891  DA=0.459  WDA=0.491
# EXOG+Tech+Sentiment expanding                  RMSE=0.05269  MAE=0.03779  DA=0.500  WDA=0.511
# EXOG+Tech+Sentiment rolling (100w)             RMSE=0.05403  MAE=0.03828  DA=0.533  WDA=0.502
# EXOG+ALL expanding                             RMSE=0.05244  MAE=0.03835  DA=0.525  WDA=0.550
# EXOG+ALL rolling (100w)                        RMSE=0.05560  MAE=0.03877  DA=0.533  WDA=0.499
# EXOG+NewsPaid expanding                        RMSE=0.05246  MAE=0.03794  DA=0.533  WDA=0.573
# EXOG+NewsPaid rolling (100w)                   RMSE=0.05405  MAE=0.03867  DA=0.451  WDA=0.446
# EXOG+Reddit+NewsPaid expanding                 RMSE=0.05264  MAE=0.03815  DA=0.516  WDA=0.579
# EXOG+Reddit+NewsPaid rolling (100w)            RMSE=0.05430  MAE=0.03875  DA=0.484  WDA=0.499
# EXOG+GS+SentimentPaid expanding                RMSE=0.05268  MAE=0.03796  DA=0.549  WDA=0.553
# EXOG+GS+SentimentPaid rolling (100w)           RMSE=0.05512  MAE=0.03881  DA=0.508  WDA=0.527
# EXOG+NonLin+SentimentPaid expanding            RMSE=0.05282  MAE=0.03865  DA=0.492  WDA=0.561
# EXOG+NonLin+SentimentPaid rolling (100w)       RMSE=0.05526  MAE=0.03946  DA=0.500  WDA=0.516
# EXOG+Tech+SentimentPaid expanding              RMSE=0.05271  MAE=0.03810  DA=0.508  WDA=0.543
# EXOG+Tech+SentimentPaid rolling (100w)         RMSE=0.05460  MAE=0.03845  DA=0.484  WDA=0.455
# EXOG+ALLPaid expanding                         RMSE=0.05233  MAE=0.03815  DA=0.516  WDA=0.550
# EXOG+ALLPaid rolling (100w)                    RMSE=0.05507  MAE=0.03885  DA=0.557  WDA=0.554
# EXOG+FRED_daily+PMI expanding                  RMSE=0.05286  MAE=0.03820  DA=0.516  WDA=0.544
# EXOG+FRED_daily+PMI rolling (100w)             RMSE=0.05420  MAE=0.03898  DA=0.500  WDA=0.465
# EXOG+FRED_daily+COT+PMI expanding              RMSE=0.05293  MAE=0.03834  DA=0.525  WDA=0.522
# EXOG+FRED_daily+COT+PMI rolling (100w)         RMSE=0.05521  MAE=0.03930  DA=0.475  WDA=0.474
# EXOG+ALL+PMI expanding                         RMSE=0.05267  MAE=0.03820  DA=0.516  WDA=0.558
# EXOG+ALL+PMI rolling (100w)                    RMSE=0.05529  MAE=0.03850  DA=0.525  WDA=0.530
# BestLag-All expanding                          RMSE=0.05328  MAE=0.03825  DA=0.541  WDA=0.548
# BestLag-All rolling (100w)                     RMSE=0.05514  MAE=0.03920  DA=0.475  WDA=0.486
# BestLag-Sig90 expanding                        RMSE=0.05284  MAE=0.03798  DA=0.525  WDA=0.560
# BestLag-Sig90 rolling (100w)                   RMSE=0.05459  MAE=0.03858  DA=0.533  WDA=0.538
# BestLag-Sig expanding                          RMSE=0.05343  MAE=0.03856  DA=0.492  WDA=0.512
# BestLag-Sig rolling (100w)                     RMSE=0.05378  MAE=0.03827  DA=0.549  WDA=0.536
#
# OOS R^2 vs Drift (2025 excluded) -- >0 beats the random walk:
# ------------------------------------------------------------------------------------------
#   EXOG expanding                           R2_OS =  +0.19%   -> winner: EXOG expanding
#   EXOG rolling (100w)                      R2_OS =  -5.21%   -> winner: Drift
#   Tech expanding                           R2_OS =  +0.91%   -> winner: Tech expanding
#   Tech rolling (100w)                      R2_OS =  -5.99%   -> winner: Drift
#   EXOG+GS expanding                        R2_OS =  -0.41%   -> winner: Drift
#   EXOG+GS rolling (100w)                   R2_OS =  -5.69%   -> winner: Drift
#   EXOG+NonLin expanding                    R2_OS =  +1.64%   -> winner: EXOG+NonLin expanding
#   EXOG+NonLin rolling (100w)               R2_OS =  -7.67%   -> winner: Drift
#   EXOG+Tech expanding                      R2_OS =  -1.56%   -> winner: Drift
#   EXOG+Tech rolling (100w)                 R2_OS =  -6.44%   -> winner: Drift
#   EXOG+Macro expanding                     R2_OS =  -5.65%   -> winner: Drift
#   EXOG+Macro rolling (100w)                R2_OS =  -9.63%   -> winner: Drift
#   EXOG+FRED_daily expanding                R2_OS =  -0.16%   -> winner: Drift
#   EXOG+FRED_daily rolling (100w)           R2_OS =  -6.32%   -> winner: Drift
#   EXOG+COT expanding                       R2_OS =  +0.63%   -> winner: EXOG+COT expanding
#   EXOG+COT rolling (100w)                  R2_OS =  -6.95%   -> winner: Drift
#   EXOG+FRED_daily+COT expanding            R2_OS =  +0.33%   -> winner: EXOG+FRED_daily+COT expanding
#   EXOG+FRED_daily+COT rolling (100w)       R2_OS =  -7.08%   -> winner: Drift
#   EXOG+Reddit+News expanding               R2_OS =  -2.96%   -> winner: Drift
#   EXOG+Reddit+News rolling (100w)          R2_OS =  -6.14%   -> winner: Drift
#   EXOG+Reddit expanding                    R2_OS =  -0.49%   -> winner: Drift
#   EXOG+Reddit rolling (100w)               R2_OS =  -6.14%   -> winner: Drift
#   EXOG+News expanding                      R2_OS =  -0.49%   -> winner: Drift
#   EXOG+News rolling (100w)                 R2_OS =  -4.11%   -> winner: Drift
#   EXOG+GS+Sentiment expanding              R2_OS =  -4.04%   -> winner: Drift
#   EXOG+GS+Sentiment rolling (100w)         R2_OS = -10.56%   -> winner: Drift
#   EXOG+NonLin+Sentiment expanding          R2_OS =  +0.96%   -> winner: EXOG+NonLin+Sentiment expanding
#   EXOG+NonLin+Sentiment rolling (100w)     R2_OS =  -6.59%   -> winner: Drift
#   EXOG+Tech+Sentiment expanding            R2_OS =  +0.23%   -> winner: EXOG+Tech+Sentiment expanding
#   EXOG+Tech+Sentiment rolling (100w)       R2_OS =  -4.91%   -> winner: Drift
#   EXOG+ALL expanding                       R2_OS =  +1.19%   -> winner: EXOG+ALL expanding
#   EXOG+ALL rolling (100w)                  R2_OS = -11.07%   -> winner: Drift
#   EXOG+NewsPaid expanding                  R2_OS =  +1.12%   -> winner: EXOG+NewsPaid expanding
#   EXOG+NewsPaid rolling (100w)             R2_OS =  -4.98%   -> winner: Drift
#   EXOG+Reddit+NewsPaid expanding           R2_OS =  +0.44%   -> winner: EXOG+Reddit+NewsPaid expanding
#   EXOG+Reddit+NewsPaid rolling (100w)      R2_OS =  -5.95%   -> winner: Drift
#   EXOG+GS+SentimentPaid expanding          R2_OS =  +0.28%   -> winner: EXOG+GS+SentimentPaid expanding
#   EXOG+GS+SentimentPaid rolling (100w)     R2_OS =  -9.19%   -> winner: Drift
#   EXOG+NonLin+SentimentPaid expanding      R2_OS =  -0.25%   -> winner: Drift
#   EXOG+NonLin+SentimentPaid rolling (100w) R2_OS =  -9.72%   -> winner: Drift
#   EXOG+Tech+SentimentPaid expanding        R2_OS =  +0.16%   -> winner: EXOG+Tech+SentimentPaid expanding
#   EXOG+Tech+SentimentPaid rolling (100w)   R2_OS =  -7.13%   -> winner: Drift
#   EXOG+ALLPaid expanding                   R2_OS =  +1.59%   -> winner: EXOG+ALLPaid expanding
#   EXOG+ALLPaid rolling (100w)              R2_OS =  -9.00%   -> winner: Drift
#   EXOG+FRED_daily+PMI expanding            R2_OS =  -0.41%   -> winner: Drift
#   EXOG+FRED_daily+PMI rolling (100w)       R2_OS =  -5.54%   -> winner: Drift
#   EXOG+FRED_daily+COT+PMI expanding        R2_OS =  -0.67%   -> winner: Drift
#   EXOG+FRED_daily+COT+PMI rolling (100w)   R2_OS =  -9.52%   -> winner: Drift
#   EXOG+ALL+PMI expanding                   R2_OS =  +0.30%   -> winner: EXOG+ALL+PMI expanding
#   EXOG+ALL+PMI rolling (100w)              R2_OS =  -9.84%   -> winner: Drift
#   BestLag-All expanding                    R2_OS =  -2.00%   -> winner: Drift
#   BestLag-All rolling (100w)               R2_OS =  -9.24%   -> winner: Drift
#   BestLag-Sig90 expanding                  R2_OS =  -0.33%   -> winner: Drift
#   BestLag-Sig90 rolling (100w)             R2_OS =  -7.08%   -> winner: Drift
#   BestLag-Sig expanding                    R2_OS =  -2.58%   -> winner: Drift
#   BestLag-Sig rolling (100w)               R2_OS =  -3.92%   -> winner: Drift
#
# DM -- vs Drift floor, 2025 excluded [squared error]:
# ------------------------------------------------------------------------------------------
# Drift                                    vs EXOG expanding                            DM=+0.225  p=0.822  (ns)  -> winner: tie
# Drift                                    vs EXOG rolling (100w)                       DM=-1.646  p=0.100  (ns)  -> winner: tie
# Drift                                    vs Tech expanding                            DM=+0.233  p=0.816  (ns)  -> winner: tie
# Drift                                    vs Tech rolling (100w)                       DM=-0.756  p=0.450  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS expanding                         DM=-0.271  p=0.786  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS rolling (100w)                    DM=-0.851  p=0.395  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin expanding                     DM=+0.637  p=0.524  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin rolling (100w)                DM=-1.922  p=0.055  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech expanding                       DM=-0.411  p=0.681  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech rolling (100w)                  DM=-0.822  p=0.411  (ns)  -> winner: tie
# Drift                                    vs EXOG+Macro expanding                      DM=-1.029  p=0.303  (ns)  -> winner: tie
# Drift                                    vs EXOG+Macro rolling (100w)                 DM=-1.200  p=0.230  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily expanding                 DM=-0.203  p=0.839  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily rolling (100w)            DM=-2.147  p=0.032  *     -> winner: Drift
# Drift                                    vs EXOG+COT expanding                        DM=+0.581  p=0.561  (ns)  -> winner: tie
# Drift                                    vs EXOG+COT rolling (100w)                   DM=-1.272  p=0.203  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT expanding             DM=+0.458  p=0.647  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT rolling (100w)        DM=-1.437  p=0.151  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+News expanding                DM=-0.876  p=0.381  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+News rolling (100w)           DM=-1.938  p=0.053  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit expanding                     DM=-0.310  p=0.756  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit rolling (100w)                DM=-1.918  p=0.055  (ns)  -> winner: tie
# Drift                                    vs EXOG+News expanding                       DM=-0.267  p=0.790  (ns)  -> winner: tie
# Drift                                    vs EXOG+News rolling (100w)                  DM=-1.351  p=0.177  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+Sentiment expanding               DM=-0.825  p=0.409  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+Sentiment rolling (100w)          DM=-1.205  p=0.228  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+Sentiment expanding           DM=+0.311  p=0.756  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+Sentiment rolling (100w)      DM=-1.683  p=0.092  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+Sentiment expanding             DM=+0.055  p=0.956  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+Sentiment rolling (100w)        DM=-0.696  p=0.486  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL expanding                        DM=+0.186  p=0.853  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL rolling (100w)                   DM=-1.163  p=0.245  (ns)  -> winner: tie
# Drift                                    vs EXOG+NewsPaid expanding                   DM=+0.981  p=0.327  (ns)  -> winner: tie
# Drift                                    vs EXOG+NewsPaid rolling (100w)              DM=-1.354  p=0.176  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+NewsPaid expanding            DM=+0.319  p=0.750  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+NewsPaid rolling (100w)       DM=-1.456  p=0.145  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+SentimentPaid expanding           DM=+0.118  p=0.906  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+SentimentPaid rolling (100w)      DM=-1.061  p=0.289  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+SentimentPaid expanding       DM=-0.058  p=0.954  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+SentimentPaid rolling (100w)  DM=-1.849  p=0.064  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+SentimentPaid expanding         DM=+0.039  p=0.969  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+SentimentPaid rolling (100w)    DM=-0.849  p=0.396  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALLPaid expanding                    DM=+0.507  p=0.612  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALLPaid rolling (100w)               DM=-1.025  p=0.306  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+PMI expanding             DM=-0.492  p=0.623  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+PMI rolling (100w)        DM=-1.758  p=0.079  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT+PMI expanding         DM=-0.774  p=0.439  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT+PMI rolling (100w)    DM=-1.687  p=0.092  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL+PMI expanding                    DM=+0.043  p=0.966  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL+PMI rolling (100w)               DM=-1.040  p=0.299  (ns)  -> winner: tie
# Drift                                    vs BestLag-All expanding                     DM=-0.430  p=0.667  (ns)  -> winner: tie
# Drift                                    vs BestLag-All rolling (100w)                DM=-1.188  p=0.235  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig90 expanding                   DM=-0.136  p=0.892  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig90 rolling (100w)              DM=-0.922  p=0.356  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig expanding                     DM=-0.735  p=0.462  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig rolling (100w)                DM=-0.562  p=0.574  (ns)  -> winner: tie
#
# DM -- vs Drift floor, 2025 excluded [absolute-error loss, robustness]:
# ------------------------------------------------------------------------------------------
# Drift                                    vs EXOG expanding                            DM=-0.814  p=0.415  (ns)  -> winner: tie
# Drift                                    vs EXOG rolling (100w)                       DM=-1.503  p=0.133  (ns)  -> winner: tie
# Drift                                    vs Tech expanding                            DM=-0.040  p=0.968  (ns)  -> winner: tie
# Drift                                    vs Tech rolling (100w)                       DM=-0.248  p=0.804  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS expanding                         DM=-0.217  p=0.828  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS rolling (100w)                    DM=-0.469  p=0.639  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin expanding                     DM=-1.075  p=0.282  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin rolling (100w)                DM=-1.676  p=0.094  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech expanding                       DM=-0.466  p=0.641  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech rolling (100w)                  DM=-0.262  p=0.793  (ns)  -> winner: tie
# Drift                                    vs EXOG+Macro expanding                      DM=-1.146  p=0.252  (ns)  -> winner: tie
# Drift                                    vs EXOG+Macro rolling (100w)                 DM=-1.091  p=0.275  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily expanding                 DM=-0.952  p=0.341  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily rolling (100w)            DM=-1.806  p=0.071  (ns)  -> winner: tie
# Drift                                    vs EXOG+COT expanding                        DM=-0.370  p=0.711  (ns)  -> winner: tie
# Drift                                    vs EXOG+COT rolling (100w)                   DM=-1.029  p=0.303  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT expanding             DM=-0.481  p=0.630  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT rolling (100w)        DM=-1.202  p=0.229  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+News expanding                DM=-0.915  p=0.360  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+News rolling (100w)           DM=-1.789  p=0.074  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit expanding                     DM=-0.795  p=0.427  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit rolling (100w)                DM=-1.318  p=0.188  (ns)  -> winner: tie
# Drift                                    vs EXOG+News expanding                       DM=-0.400  p=0.689  (ns)  -> winner: tie
# Drift                                    vs EXOG+News rolling (100w)                  DM=-1.150  p=0.250  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+Sentiment expanding               DM=-0.484  p=0.628  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+Sentiment rolling (100w)          DM=-0.706  p=0.480  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+Sentiment expanding           DM=-1.306  p=0.192  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+Sentiment rolling (100w)      DM=-1.204  p=0.229  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+Sentiment expanding             DM=+0.250  p=0.802  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+Sentiment rolling (100w)        DM=-0.252  p=0.801  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL expanding                        DM=-0.332  p=0.740  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL rolling (100w)                   DM=-0.526  p=0.599  (ns)  -> winner: tie
# Drift                                    vs EXOG+NewsPaid expanding                   DM=+0.072  p=0.943  (ns)  -> winner: tie
# Drift                                    vs EXOG+NewsPaid rolling (100w)              DM=-0.975  p=0.329  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+NewsPaid expanding            DM=-0.576  p=0.565  (ns)  -> winner: tie
# Drift                                    vs EXOG+Reddit+NewsPaid rolling (100w)       DM=-1.088  p=0.276  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+SentimentPaid expanding           DM=+0.003  p=0.997  (ns)  -> winner: tie
# Drift                                    vs EXOG+GS+SentimentPaid rolling (100w)      DM=-0.616  p=0.538  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+SentimentPaid expanding       DM=-0.975  p=0.330  (ns)  -> winner: tie
# Drift                                    vs EXOG+NonLin+SentimentPaid rolling (100w)  DM=-1.454  p=0.146  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+SentimentPaid expanding         DM=-0.187  p=0.851  (ns)  -> winner: tie
# Drift                                    vs EXOG+Tech+SentimentPaid rolling (100w)    DM=-0.363  p=0.716  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALLPaid expanding                    DM=-0.293  p=0.770  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALLPaid rolling (100w)               DM=-0.693  p=0.488  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+PMI expanding             DM=-0.749  p=0.454  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+PMI rolling (100w)        DM=-1.482  p=0.138  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT+PMI expanding         DM=-1.182  p=0.237  (ns)  -> winner: tie
# Drift                                    vs EXOG+FRED_daily+COT+PMI rolling (100w)    DM=-1.415  p=0.157  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL+PMI expanding                    DM=-0.190  p=0.849  (ns)  -> winner: tie
# Drift                                    vs EXOG+ALL+PMI rolling (100w)               DM=-0.332  p=0.740  (ns)  -> winner: tie
# Drift                                    vs BestLag-All expanding                     DM=-0.399  p=0.690  (ns)  -> winner: tie
# Drift                                    vs BestLag-All rolling (100w)                DM=-1.032  p=0.302  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig90 expanding                   DM=-0.033  p=0.973  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig90 rolling (100w)              DM=-0.483  p=0.629  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig expanding                     DM=-1.098  p=0.272  (ns)  -> winner: tie
# Drift                                    vs BestLag-Sig rolling (100w)                DM=-0.227  p=0.821  (ns)  -> winner: tie
#
# Pesaran-Timmermann (2025 excluded) -- directional sign test:
# ------------------------------------------------------------------------------------------
# EXOG expanding                            DA=0.492  DA|indep=0.500  PT=-0.277  p=0.782  (ns)  -> winner: tie (chance)
# EXOG rolling (100w)                       DA=0.484  DA|indep=0.500  PT=-0.375  p=0.708  (ns)  -> winner: tie (chance)
# Tech expanding                            DA=0.508  DA|indep=0.500  PT=+0.317  p=0.751  (ns)  -> winner: tie (chance)
# Tech rolling (100w)                       DA=0.557  DA|indep=0.500  PT=+1.273  p=0.203  (ns)  -> winner: tie (chance)
# EXOG+GS expanding                         DA=0.516  DA|indep=0.500  PT=+0.539  p=0.590  (ns)  -> winner: tie (chance)
# EXOG+GS rolling (100w)                    DA=0.508  DA|indep=0.500  PT=+0.185  p=0.853  (ns)  -> winner: tie (chance)
# EXOG+NonLin expanding                     DA=0.500  DA|indep=0.500  PT=+0.000  p=1.000  (ns)  -> winner: tie (chance)
# EXOG+NonLin rolling (100w)                DA=0.475  DA|indep=0.500  PT=-0.556  p=0.578  (ns)  -> winner: tie (chance)
# EXOG+Tech expanding                       DA=0.500  DA|indep=0.500  PT=+0.000  p=1.000  (ns)  -> winner: tie (chance)
# EXOG+Tech rolling (100w)                  DA=0.500  DA|indep=0.500  PT=+0.000  p=1.000  (ns)  -> winner: tie (chance)
# EXOG+Macro expanding                      DA=0.443  DA|indep=0.500  PT=-1.686  p=0.092  (ns)  -> winner: tie (chance)
# EXOG+Macro rolling (100w)                 DA=0.467  DA|indep=0.500  PT=-0.785  p=0.432  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily expanding                 DA=0.508  DA|indep=0.500  PT=+0.263  p=0.793  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily rolling (100w)            DA=0.459  DA|indep=0.500  PT=-0.914  p=0.361  (ns)  -> winner: tie (chance)
# EXOG+COT expanding                        DA=0.492  DA|indep=0.500  PT=-0.251  p=0.802  (ns)  -> winner: tie (chance)
# EXOG+COT rolling (100w)                   DA=0.500  DA|indep=0.500  PT=+0.000  p=1.000  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+COT expanding             DA=0.508  DA|indep=0.500  PT=+0.263  p=0.793  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+COT rolling (100w)        DA=0.525  DA|indep=0.500  PT=+0.560  p=0.575  (ns)  -> winner: tie (chance)
# EXOG+Reddit+News expanding                DA=0.492  DA|indep=0.500  PT=-0.263  p=0.793  (ns)  -> winner: tie (chance)
# EXOG+Reddit+News rolling (100w)           DA=0.508  DA|indep=0.500  PT=+0.190  p=0.849  (ns)  -> winner: tie (chance)
# EXOG+Reddit expanding                     DA=0.516  DA|indep=0.500  PT=+0.444  p=0.657  (ns)  -> winner: tie (chance)
# EXOG+Reddit rolling (100w)                DA=0.557  DA|indep=0.500  PT=+1.332  p=0.183  (ns)  -> winner: tie (chance)
# EXOG+News expanding                       DA=0.492  DA|indep=0.500  PT=-0.251  p=0.802  (ns)  -> winner: tie (chance)
# EXOG+News rolling (100w)                  DA=0.467  DA|indep=0.500  PT=-0.775  p=0.439  (ns)  -> winner: tie (chance)
# EXOG+GS+Sentiment expanding               DA=0.541  DA|indep=0.500  PT=+1.095  p=0.274  (ns)  -> winner: tie (chance)
# EXOG+GS+Sentiment rolling (100w)          DA=0.516  DA|indep=0.500  PT=+0.370  p=0.712  (ns)  -> winner: tie (chance)
# EXOG+NonLin+Sentiment expanding           DA=0.492  DA|indep=0.500  PT=-0.277  p=0.782  (ns)  -> winner: tie (chance)
# EXOG+NonLin+Sentiment rolling (100w)      DA=0.459  DA|indep=0.500  PT=-0.975  p=0.330  (ns)  -> winner: tie (chance)
# EXOG+Tech+Sentiment expanding             DA=0.500  DA|indep=0.500  PT=+0.000  p=1.000  (ns)  -> winner: tie (chance)
# EXOG+Tech+Sentiment rolling (100w)        DA=0.533  DA|indep=0.500  PT=+0.732  p=0.464  (ns)  -> winner: tie (chance)
# EXOG+ALL expanding                        DA=0.525  DA|indep=0.500  PT=+0.614  p=0.539  (ns)  -> winner: tie (chance)
# EXOG+ALL rolling (100w)                   DA=0.533  DA|indep=0.500  PT=+0.732  p=0.464  (ns)  -> winner: tie (chance)
# EXOG+NewsPaid expanding                   DA=0.533  DA|indep=0.500  PT=+0.844  p=0.398  (ns)  -> winner: tie (chance)
# EXOG+NewsPaid rolling (100w)              DA=0.451  DA|indep=0.500  PT=-1.136  p=0.256  (ns)  -> winner: tie (chance)
# EXOG+Reddit+NewsPaid expanding            DA=0.516  DA|indep=0.500  PT=+0.513  p=0.608  (ns)  -> winner: tie (chance)
# EXOG+Reddit+NewsPaid rolling (100w)       DA=0.484  DA|indep=0.500  PT=-0.383  p=0.702  (ns)  -> winner: tie (chance)
# EXOG+GS+SentimentPaid expanding           DA=0.549  DA|indep=0.500  PT=+1.473  p=0.141  (ns)  -> winner: tie (chance)
# EXOG+GS+SentimentPaid rolling (100w)      DA=0.508  DA|indep=0.500  PT=+0.184  p=0.854  (ns)  -> winner: tie (chance)
# EXOG+NonLin+SentimentPaid expanding       DA=0.492  DA|indep=0.500  PT=-0.205  p=0.838  (ns)  -> winner: tie (chance)
# EXOG+NonLin+SentimentPaid rolling (100w)  DA=0.500  DA|indep=0.500  PT=+0.000  p=1.000  (ns)  -> winner: tie (chance)
# EXOG+Tech+SentimentPaid expanding         DA=0.508  DA|indep=0.500  PT=+0.277  p=0.782  (ns)  -> winner: tie (chance)
# EXOG+Tech+SentimentPaid rolling (100w)    DA=0.484  DA|indep=0.500  PT=-0.364  p=0.716  (ns)  -> winner: tie (chance)
# EXOG+ALLPaid expanding                    DA=0.516  DA|indep=0.500  PT=+0.663  p=0.507  (ns)  -> winner: tie (chance)
# EXOG+ALLPaid rolling (100w)               DA=0.557  DA|indep=0.500  PT=+1.298  p=0.194  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+PMI expanding             DA=0.516  DA|indep=0.500  PT=+0.432  p=0.665  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+PMI rolling (100w)        DA=0.500  DA|indep=0.500  PT=+0.000  p=1.000  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+COT+PMI expanding         DA=0.525  DA|indep=0.500  PT=+0.788  p=0.431  (ns)  -> winner: tie (chance)
# EXOG+FRED_daily+COT+PMI rolling (100w)    DA=0.475  DA|indep=0.500  PT=-0.560  p=0.575  (ns)  -> winner: tie (chance)
# EXOG+ALL+PMI expanding                    DA=0.516  DA|indep=0.500  PT=+0.399  p=0.690  (ns)  -> winner: tie (chance)
# EXOG+ALL+PMI rolling (100w)               DA=0.525  DA|indep=0.500  PT=+0.550  p=0.582  (ns)  -> winner: tie (chance)
# BestLag-All expanding                     DA=0.541  DA|indep=0.500  PT=+0.942  p=0.346  (ns)  -> winner: tie (chance)
# BestLag-All rolling (100w)                DA=0.475  DA|indep=0.500  PT=-0.571  p=0.568  (ns)  -> winner: tie (chance)
# BestLag-Sig90 expanding                   DA=0.525  DA|indep=0.500  PT=+0.697  p=0.486  (ns)  -> winner: tie (chance)
# BestLag-Sig90 rolling (100w)              DA=0.533  DA|indep=0.500  PT=+0.757  p=0.449  (ns)  -> winner: tie (chance)
# BestLag-Sig expanding                     DA=0.492  DA|indep=0.500  PT=-0.241  p=0.810  (ns)  -> winner: tie (chance)
# BestLag-Sig rolling (100w)                DA=0.549  DA|indep=0.500  PT=+1.125  p=0.260  (ns)  -> winner: tie (chance)

# %% [markdown]
# ## 9. 2026 zoom — actual vs best variants
#
# Two panels (WDA-best | RMSE-best) on the 2026 YTD slice, drift overlaid. The RMSE-best hugs the
# drift (minimising squared error ≈ reproducing the random walk); the WDA-best is the directional bettor.

# %%
df26 = pd.DataFrame({'actual': y_test, 'drift': drift_pred,
                     'wda_best': best_pred, 'rmse_best': best_pred_rmse},
                    index=test_index).loc['2026':]

if df26.empty:
    print('No 2026 data in test set yet.')
else:
    fig, axes = plt.subplots(1, 2, figsize=(14, 4), sharex=True, sharey=True)
    panels = [('wda_best', best_name, '#1f77b4', 'WDA-best'),
              ('rmse_best', best_name_rmse, '#d62728', 'RMSE-best')]
    for ax, (col, vname, color, tag) in zip(axes, panels):
        ax.plot(df26.index, df26['actual'], color='black',    lw=1.5, marker='o', ms=4, label='Actual')
        ax.plot(df26.index, df26['drift'],  color='seagreen', lw=1.3, ls=':',  label='Drift')
        ax.plot(df26.index, df26[col],      color=color,      lw=1.5, marker='o', ms=4, ls='--', label=vname)
        ax.axhline(0, color='grey', lw=0.6, ls=':')
        ax.set_title(f'2026 -- actual vs drift vs {tag}', fontsize=11)
        ax.set_xlabel('Week')
        ax.legend(fontsize=8)
    axes[0].set_ylabel('Weekly log-return')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 10. Feature importance (EXOG+ALL model)
#
# **Permutation importance (not gain)** from a single XGBoost fit on the **full EXOG+ALL feature set** (train+val) with that rung's tuned hyperparameters, then probed **out-of-sample on the test window**. The full set is deliberate: importance is a *ranking* exercise, so every candidate predictor has to be in the model to be ranked — restricting to the EXOG base would only rank the cross-asset lags and discard the whole "do macro / COT / sentiment matter?" question.
#
# *Why permutation, not gain.* Gain (XGBoost's default `.feature_importances_`) is read off the trees *during training* from each feature's average loss reduction at its splits — an in-sample, model-internal measure that can rank a feature high for how the boosting used it rather than whether it generalises. Permutation instead **freezes the fitted model** and, one feature at a time, **shuffles that column on the test rows and measures the RMSE increase** — a direct read of out-of-sample contribution. (Caveat: with correlated predictors a shuffled feature can be "covered" by its correlate, so both look weaker than they are — read groups, not single bars; SHAP would handle this but is overkill for a descriptive plot.)
#
# Descriptive only; the load-bearing verdict is the Drift-floor DM battery in §8.
#
# **Reading the plot:** each bar is the *mean* RMSE increase across the 30 shuffle repeats — longer = the model leaned on that feature more; the whiskers are the spread across repeats, so wide whiskers mean an unstable estimate (trust that feature's rank less); the dashed line is zero, and bars that barely reach it — or fall to its left — added essentially nothing (shuffling them didn't hurt, or even helped by chance). Expect most bars near zero here: with no variant beating drift out-of-sample, that *is* the signature of a feature set carrying no exploitable signal.

# %%
# Fit one XGBoost on the full EXOG+ALL feature set (train+val) with its tuned params, then PROBE it
# out-of-sample: permutation importance on the held-out test window. The fitted model is frozen;
# each feature column is shuffled across the test rows and the resulting RMSE increase is its score.
from sklearn.inspection import permutation_importance

imp_feats = features_all[ALL_BASE].copy()
# Importance superset: EXOG+ALL + paid-news title + PMI, so the new features rank alongside GDELT
# news / cross-assets (descriptive; reuses the EXOG+ALL tuned params, not a separate tuned rung).
for col_name, series in {**ALL_EXTRA, **NEWSPAID_COLS, **PMI_COLS}.items():
    imp_feats[col_name] = series.reindex(imp_feats.index).ffill()
imp_cols = imp_feats.columns.tolist()

X_tr = imp_feats.iloc[:n_train][imp_cols].values
y_tr = all_w[TARGET].iloc[:n_train].values
tr_mask = ~np.isnan(X_tr).any(axis=1)
X_te = imp_feats.iloc[n_train:][imp_cols].values
y_te = all_w[TARGET].iloc[n_train:].values
te_mask = ~np.isnan(X_te).any(axis=1) & ~np.isnan(y_te)

imp_model = XGBRegressor(random_state=42, verbosity=0, **variant_params['EXOG+ALL'])
imp_model.fit(X_tr[tr_mask], y_tr[tr_mask])

# Permutation importance on the held-out test window (frozen model; RMSE increase per shuffled feature).
perm = permutation_importance(imp_model, X_te[te_mask], y_te[te_mask],
                              scoring='neg_root_mean_squared_error', n_repeats=30,
                              random_state=42, n_jobs=-1)
importances = pd.Series(perm.importances_mean, index=imp_cols).sort_values()
imp_std = pd.Series(perm.importances_std, index=imp_cols).reindex(importances.index)

fig, ax = plt.subplots(figsize=(7, max(4, 0.25 * len(imp_cols))))
importances.plot.barh(ax=ax, color='steelblue', xerr=imp_std)
ax.axvline(0, color='black', lw=0.6, ls='--')
ax.set_title('XGBoost permutation importance (OOS test window) -- EXOG+ALL + paid-news + PMI')
ax.set_xlabel('Mean RMSE increase when shuffled')
plt.tight_layout()
plt.show()
print(importances.sort_values(ascending=False).head(20))
# Out:
# gold_return_lag1_sq               0.001030
# silver_lag2_sq                    0.000324
# macd_hist_lag1                    0.000179
# gs_ratio_z_lag1                   0.000170
# china_pmi_proxy_lag1              0.000156
# news_paid_sentiment_title_lag1    0.000129
# sp500_return_lag1                 0.000127
# gold_return_lag1                  0.000104
# silver_lag3                       0.000093
# news_sentiment_lag1               0.000092
# cot_mm_net_pct_lag1               0.000059
# vix_return_lag1                   0.000043
# oil_return_lag1                   0.000025
# copper_return_lag1_sq             0.000021
# jobless_chg_lag1                  0.000018
# reddit_sentiment_lag1             0.000015
# roc_13w_lag1                      0.000008
# copper_return_lag1                0.000007
# usd_return_lag1                   0.000007
# silver_lag2                       0.000002
# dtype: float64
